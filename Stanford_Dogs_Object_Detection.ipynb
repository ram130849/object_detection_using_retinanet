# %% [markdown]
# <a href="https://colab.research.google.com/github/ram130849/object_detection_using_retinanet/blob/main/Stanford_Dogs_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %%shell
#
# # Download TorchVision repo to use some files from
# # references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 322860, done.
# remote: Counting objects: 100% (845/845), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 322860 (delta 692), reused 815 (delta 673), pack-reused 322015
# Receiving objects: 100% (322860/322860), 654.53 MiB | 17.91 MiB/s, done.
# Resolving deltas: 100% (296722/296722), done.

# %%
# !tar -xvf  '/content/gdrive/MyDrive/images.tar' -C '/content/'
# !tar -xvf  '/content/gdrive/MyDrive/annotations.tar' -C '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
# Annotation/n02108089-boxer/n02108089_1560
# Annotation/n02108089-boxer/n02108089_15702
# Annotation/n02108089-boxer/n02108089_1571
# Annotation/n02108089-boxer/n02108089_1575
# Annotation/n02108089-boxer/n02108089_1619
# Annotation/n02108089-boxer/n02108089_1626
# Annotation/n02108089-boxer/n02108089_1654
# Annotation/n02108089-boxer/n02108089_1672
# Annotation/n02108089-boxer/n02108089_1675
# Annotation/n02108089-boxer/n02108089_1690
# Annotation/n02108089-boxer/n02108089_1748
# Annotation/n02108089-boxer/n02108089_1757
# Annotation/n02108089-boxer/n02108089_1775
# Annotation/n02108089-boxer/n02108089_1859
# Annotation/n02108089-boxer/n02108089_1912
# Annotation/n02108089-boxer/n02108089_1956
# Annotation/n02108089-boxer/n02108089_200
# Annotation/n02108089-boxer/n02108089_2007
# Annotation/n02108089-boxer/n02108089_2056
# Annotation/n02108089-boxer/n02108089_2106
# Annotation/n02108089-boxer/n02108089_2355
# Annotation/n02108089-boxer/n02108089_2360
# Annotation/n02108089-boxer/n02108089_2367
# Annotation/n02108089-boxer/n02108089_2432
# Annotation/n02108089-boxer/n02108089_2482
# Annotation/n02108089-boxer/n02108089_2526
# Annotation/n02108089-boxer/n02108089_2608
# Annotation/n02108089-boxer/n02108089_2653
# Annotation/n02108089-boxer/n02108089_2670
# Annotation/n02108089-boxer/n02108089_268
# Annotation/n02108089-boxer/n02108089_2718
# Annotation/n02108089-boxer/n02108089_2723
# Annotation/n02108089-boxer/n02108089_2740
# Annotation/n02108089-boxer/n02108089_2741
# Annotation/n02108089-boxer/n02108089_2791
# Annotation/n02108089-boxer/n02108089_2796
# Annotation/n02108089-boxer/n02108089_2815
# Annotation/n02108089-boxer/n02108089_2831
# Annotation/n02108089-boxer/n02108089_2917
# Annotation/n02108089-boxer/n02108089_2953
# Annotation/n02108089-boxer/n02108089_3028
# Annotation/n02108089-boxer/n02108089_3162
# Annotation/n02108089-boxer/n02108089_3236
# Annotation/n02108089-boxer/n02108089_3248
# Annotation/n02108089-boxer/n02108089_3258
# Annotation/n02108089-boxer/n02108089_3269
# Annotation/n02108089-boxer/n02108089_3365
# Annotation/n02108089-boxer/n02108089_3395
# Annotation/n02108089-boxer/n02108089_3400
# Annotation/n02108089-boxer/n02108089_3412
# Annotation/n02108089-boxer/n02108089_3547
# Annotation/n02108089-boxer/n02108089_3557
# Annotation/n02108089-boxer/n02108089_3669
# Annotation/n02108089-boxer/n02108089_3899
# Annotation/n02108089-boxer/n02108089_395
# Annotation/n02108089-boxer/n02108089_4002
# Annotation/n02108089-boxer/n02108089_4042
# Annotation/n02108089-boxer/n02108089_4076
# Annotation/n02108089-boxer/n02108089_4119
# Annotation/n02108089-boxer/n02108089_4158
# Annotation/n02108089-boxer/n02108089_4440
# Annotation/n02108089-boxer/n02108089_4486
# Annotation/n02108089-boxer/n02108089_4681
# Annotation/n02108089-boxer/n02108089_4730
# Annotation/n02108089-boxer/n02108089_485
# Annotation/n02108089-boxer/n02108089_4865
# Annotation/n02108089-boxer/n02108089_4989
# Annotation/n02108089-boxer/n02108089_5043
# Annotation/n02108089-boxer/n02108089_522
# Annotation/n02108089-boxer/n02108089_5266
# Annotation/n02108089-boxer/n02108089_530
# Annotation/n02108089-boxer/n02108089_5301
# Annotation/n02108089-boxer/n02108089_540
# Annotation/n02108089-boxer/n02108089_5423
# Annotation/n02108089-boxer/n02108089_5599
# Annotation/n02108089-boxer/n02108089_5614
# Annotation/n02108089-boxer/n02108089_5753
# Annotation/n02108089-boxer/n02108089_5977
# Annotation/n02108089-boxer/n02108089_6008
# Annotation/n02108089-boxer/n02108089_6223
# Annotation/n02108089-boxer/n02108089_625
# Annotation/n02108089-boxer/n02108089_6295
# Annotation/n02108089-boxer/n02108089_6418
# Annotation/n02108089-boxer/n02108089_6429
# Annotation/n02108089-boxer/n02108089_6583
# Annotation/n02108089-boxer/n02108089_69
# Annotation/n02108089-boxer/n02108089_7259
# Annotation/n02108089-boxer/n02108089_7319
# Annotation/n02108089-boxer/n02108089_7431
# Annotation/n02108089-boxer/n02108089_7456
# Annotation/n02108089-boxer/n02108089_770
# Annotation/n02108089-boxer/n02108089_78
# Annotation/n02108089-boxer/n02108089_7853
# Annotation/n02108089-boxer/n02108089_813
# Annotation/n02108089-boxer/n02108089_836
# Annotation/n02108089-boxer/n02108089_849
# Annotation/n02108089-boxer/n02108089_8739
# Annotation/n02108089-boxer/n02108089_8969
# Annotation/n02108089-boxer/n02108089_9045
# Annotation/n02108089-boxer/n02108089_9076
# Annotation/n02108089-boxer/n02108089_922
# Annotation/n02108089-boxer/n02108089_926
# Annotation/n02108089-boxer/n02108089_931
# Annotation/n02108089-boxer/n02108089_959
# Annotation/n02108089-boxer/n02108089_9724
# Annotation/n02108089-boxer/n02108089_9778
# Annotation/n02108089-boxer/n02108089_995
# Annotation/n02108422-bull_mastiff/
# Annotation/n02108422-bull_mastiff/n02108422_1013
# Annotation/n02108422-bull_mastiff/n02108422_1016
# Annotation/n02108422-bull_mastiff/n02108422_1017
# Annotation/n02108422-bull_mastiff/n02108422_1079
# Annotation/n02108422-bull_mastiff/n02108422_1096
# Annotation/n02108422-bull_mastiff/n02108422_1166
# Annotation/n02108422-bull_mastiff/n02108422_1242
# Annotation/n02108422-bull_mastiff/n02108422_1305
# Annotation/n02108422-bull_mastiff/n02108422_1425
# Annotation/n02108422-bull_mastiff/n02108422_1442
# Annotation/n02108422-bull_mastiff/n02108422_1445
# Annotation/n02108422-bull_mastiff/n02108422_1507
# Annotation/n02108422-bull_mastiff/n02108422_1546
# Annotation/n02108422-bull_mastiff/n02108422_1547
# Annotation/n02108422-bull_mastiff/n02108422_1548
# Annotation/n02108422-bull_mastiff/n02108422_1549
# Annotation/n02108422-bull_mastiff/n02108422_158
# Annotation/n02108422-bull_mastiff/n02108422_170
# Annotation/n02108422-bull_mastiff/n02108422_1701
# Annotation/n02108422-bull_mastiff/n02108422_1836
# Annotation/n02108422-bull_mastiff/n02108422_1869
# Annotation/n02108422-bull_mastiff/n02108422_1879
# Annotation/n02108422-bull_mastiff/n02108422_1889
# Annotation/n02108422-bull_mastiff/n02108422_1923
# Annotation/n02108422-bull_mastiff/n02108422_1939
# Annotation/n02108422-bull_mastiff/n02108422_1958
# Annotation/n02108422-bull_mastiff/n02108422_1968
# Annotation/n02108422-bull_mastiff/n02108422_1975
# Annotation/n02108422-bull_mastiff/n02108422_200
# Annotation/n02108422-bull_mastiff/n02108422_2046
# Annotation/n02108422-bull_mastiff/n02108422_2052
# Annotation/n02108422-bull_mastiff/n02108422_2053
# Annotation/n02108422-bull_mastiff/n02108422_207
# Annotation/n02108422-bull_mastiff/n02108422_2082
# Annotation/n02108422-bull_mastiff/n02108422_2094
# Annotation/n02108422-bull_mastiff/n02108422_2111
# Annotation/n02108422-bull_mastiff/n02108422_2123
# Annotation/n02108422-bull_mastiff/n02108422_2203
# Annotation/n02108422-bull_mastiff/n02108422_2207
# Annotation/n02108422-bull_mastiff/n02108422_2209
# Annotation/n02108422-bull_mastiff/n02108422_2290
# Annotation/n02108422-bull_mastiff/n02108422_2297
# Annotation/n02108422-bull_mastiff/n02108422_2338
# Annotation/n02108422-bull_mastiff/n02108422_2344
# Annotation/n02108422-bull_mastiff/n02108422_2353
# Annotation/n02108422-bull_mastiff/n02108422_2379
# Annotation/n02108422-bull_mastiff/n02108422_2404
# Annotation/n02108422-bull_mastiff/n02108422_2441
# Annotation/n02108422-bull_mastiff/n02108422_2443
# Annotation/n02108422-bull_mastiff/n02108422_2471
# Annotation/n02108422-bull_mastiff/n02108422_251
# Annotation/n02108422-bull_mastiff/n02108422_2623
# Annotation/n02108422-bull_mastiff/n02108422_2678
# Annotation/n02108422-bull_mastiff/n02108422_278
# Annotation/n02108422-bull_mastiff/n02108422_2867
# Annotation/n02108422-bull_mastiff/n02108422_2947
# Annotation/n02108422-bull_mastiff/n02108422_2949
# Annotation/n02108422-bull_mastiff/n02108422_2990
# Annotation/n02108422-bull_mastiff/n02108422_3051
# Annotation/n02108422-bull_mastiff/n02108422_3086
# Annotation/n02108422-bull_mastiff/n02108422_3101
# Annotation/n02108422-bull_mastiff/n02108422_311
# Annotation/n02108422-bull_mastiff/n02108422_3169
# Annotation/n02108422-bull_mastiff/n02108422_3177
# Annotation/n02108422-bull_mastiff/n02108422_3184
# Annotation/n02108422-bull_mastiff/n02108422_3186
# Annotation/n02108422-bull_mastiff/n02108422_3197
# Annotation/n02108422-bull_mastiff/n02108422_3235
# Annotation/n02108422-bull_mastiff/n02108422_3273
# Annotation/n02108422-bull_mastiff/n02108422_3277
# Annotation/n02108422-bull_mastiff/n02108422_3297
# Annotation/n02108422-bull_mastiff/n02108422_3379
# Annotation/n02108422-bull_mastiff/n02108422_3398
# Annotation/n02108422-bull_mastiff/n02108422_3440
# Annotation/n02108422-bull_mastiff/n02108422_347
# Annotation/n02108422-bull_mastiff/n02108422_3479
# Annotation/n02108422-bull_mastiff/n02108422_3576
# Annotation/n02108422-bull_mastiff/n02108422_3593
# Annotation/n02108422-bull_mastiff/n02108422_3618
# Annotation/n02108422-bull_mastiff/n02108422_3621
# Annotation/n02108422-bull_mastiff/n02108422_3641
# Annotation/n02108422-bull_mastiff/n02108422_3647
# Annotation/n02108422-bull_mastiff/n02108422_3708
# Annotation/n02108422-bull_mastiff/n02108422_3709
# Annotation/n02108422-bull_mastiff/n02108422_3711
# Annotation/n02108422-bull_mastiff/n02108422_3726
# Annotation/n02108422-bull_mastiff/n02108422_3749
# Annotation/n02108422-bull_mastiff/n02108422_3757
# Annotation/n02108422-bull_mastiff/n02108422_3793
# Annotation/n02108422-bull_mastiff/n02108422_3795
# Annotation/n02108422-bull_mastiff/n02108422_3911
# Annotation/n02108422-bull_mastiff/n02108422_3958
# Annotation/n02108422-bull_mastiff/n02108422_3970
# Annotation/n02108422-bull_mastiff/n02108422_3976
# Annotation/n02108422-bull_mastiff/n02108422_3985
# Annotation/n02108422-bull_mastiff/n02108422_4000
# Annotation/n02108422-bull_mastiff/n02108422_4039
# Annotation/n02108422-bull_mastiff/n02108422_4064
# Annotation/n02108422-bull_mastiff/n02108422_4099
# Annotation/n02108422-bull_mastiff/n02108422_4102
# Annotation/n02108422-bull_mastiff/n02108422_4250
# Annotation/n02108422-bull_mastiff/n02108422_4375
# Annotation/n02108422-bull_mastiff/n02108422_4396
# Annotation/n02108422-bull_mastiff/n02108422_4445
# Annotation/n02108422-bull_mastiff/n02108422_4454
# Annotation/n02108422-bull_mastiff/n02108422_4503
# Annotation/n02108422-bull_mastiff/n02108422_4520
# Annotation/n02108422-bull_mastiff/n02108422_4548
# Annotation/n02108422-bull_mastiff/n02108422_4637
# Annotation/n02108422-bull_mastiff/n02108422_4639
# Annotation/n02108422-bull_mastiff/n02108422_4735
# Annotation/n02108422-bull_mastiff/n02108422_4793
# Annotation/n02108422-bull_mastiff/n02108422_4869
# Annotation/n02108422-bull_mastiff/n02108422_4898
# Annotation/n02108422-bull_mastiff/n02108422_4945
# Annotation/n02108422-bull_mastiff/n02108422_4976
# Annotation/n02108422-bull_mastiff/n02108422_4978
# Annotation/n02108422-bull_mastiff/n02108422_5106
# Annotation/n02108422-bull_mastiff/n02108422_5117
# Annotation/n02108422-bull_mastiff/n02108422_5143
# Annotation/n02108422-bull_mastiff/n02108422_5221
# Annotation/n02108422-bull_mastiff/n02108422_5234
# Annotation/n02108422-bull_mastiff/n02108422_5260
# Annotation/n02108422-bull_mastiff/n02108422_5261
# Annotation/n02108422-bull_mastiff/n02108422_5327
# Annotation/n02108422-bull_mastiff/n02108422_5401
# Annotation/n02108422-bull_mastiff/n02108422_5432
# Annotation/n02108422-bull_mastiff/n02108422_5444
# Annotation/n02108422-bull_mastiff/n02108422_5466
# Annotation/n02108422-bull_mastiff/n02108422_5490
# Annotation/n02108422-bull_mastiff/n02108422_5563
# Annotation/n02108422-bull_mastiff/n02108422_5595
# Annotation/n02108422-bull_mastiff/n02108422_56
# Annotation/n02108422-bull_mastiff/n02108422_5609
# Annotation/n02108422-bull_mastiff/n02108422_5619
# Annotation/n02108422-bull_mastiff/n02108422_567
# Annotation/n02108422-bull_mastiff/n02108422_568
# Annotation/n02108422-bull_mastiff/n02108422_612
# Annotation/n02108422-bull_mastiff/n02108422_628
# Annotation/n02108422-bull_mastiff/n02108422_647
# Annotation/n02108422-bull_mastiff/n02108422_668
# Annotation/n02108422-bull_mastiff/n02108422_683
# Annotation/n02108422-bull_mastiff/n02108422_734
# Annotation/n02108422-bull_mastiff/n02108422_747
# Annotation/n02108422-bull_mastiff/n02108422_751
# Annotation/n02108422-bull_mastiff/n02108422_754
# Annotation/n02108422-bull_mastiff/n02108422_767
# Annotation/n02108422-bull_mastiff/n02108422_821
# Annotation/n02108422-bull_mastiff/n02108422_822
# Annotation/n02108422-bull_mastiff/n02108422_844
# Annotation/n02108422-bull_mastiff/n02108422_852
# Annotation/n02108422-bull_mastiff/n02108422_861
# Annotation/n02108422-bull_mastiff/n02108422_90
# Annotation/n02108422-bull_mastiff/n02108422_932
# Annotation/n02108422-bull_mastiff/n02108422_942
# Annotation/n02108422-bull_mastiff/n02108422_964
# Annotation/n02108551-Tibetan_mastiff/
# Annotation/n02108551-Tibetan_mastiff/n02108551_10182
# Annotation/n02108551-Tibetan_mastiff/n02108551_1025
# Annotation/n02108551-Tibetan_mastiff/n02108551_103
# Annotation/n02108551-Tibetan_mastiff/n02108551_1091
# Annotation/n02108551-Tibetan_mastiff/n02108551_1104
# Annotation/n02108551-Tibetan_mastiff/n02108551_1121
# Annotation/n02108551-Tibetan_mastiff/n02108551_11271
# Annotation/n02108551-Tibetan_mastiff/n02108551_1155
# Annotation/n02108551-Tibetan_mastiff/n02108551_11671
# Annotation/n02108551-Tibetan_mastiff/n02108551_1240
# Annotation/n02108551-Tibetan_mastiff/n02108551_12438
# Annotation/n02108551-Tibetan_mastiff/n02108551_1287
# Annotation/n02108551-Tibetan_mastiff/n02108551_13042
# Annotation/n02108551-Tibetan_mastiff/n02108551_1326
# Annotation/n02108551-Tibetan_mastiff/n02108551_13756
# Annotation/n02108551-Tibetan_mastiff/n02108551_1380
# Annotation/n02108551-Tibetan_mastiff/n02108551_1408
# Annotation/n02108551-Tibetan_mastiff/n02108551_1409
# Annotation/n02108551-Tibetan_mastiff/n02108551_143
# Annotation/n02108551-Tibetan_mastiff/n02108551_1451
# Annotation/n02108551-Tibetan_mastiff/n02108551_146
# Annotation/n02108551-Tibetan_mastiff/n02108551_1506
# Annotation/n02108551-Tibetan_mastiff/n02108551_154
# Annotation/n02108551-Tibetan_mastiff/n02108551_1543
# Annotation/n02108551-Tibetan_mastiff/n02108551_155
# Annotation/n02108551-Tibetan_mastiff/n02108551_1553
# Annotation/n02108551-Tibetan_mastiff/n02108551_1664
# Annotation/n02108551-Tibetan_mastiff/n02108551_1689
# Annotation/n02108551-Tibetan_mastiff/n02108551_1700
# Annotation/n02108551-Tibetan_mastiff/n02108551_1705
# Annotation/n02108551-Tibetan_mastiff/n02108551_1719
# Annotation/n02108551-Tibetan_mastiff/n02108551_1724
# Annotation/n02108551-Tibetan_mastiff/n02108551_1725
# Annotation/n02108551-Tibetan_mastiff/n02108551_1743
# Annotation/n02108551-Tibetan_mastiff/n02108551_175
# Annotation/n02108551-Tibetan_mastiff/n02108551_1774
# Annotation/n02108551-Tibetan_mastiff/n02108551_1794
# Annotation/n02108551-Tibetan_mastiff/n02108551_1815
# Annotation/n02108551-Tibetan_mastiff/n02108551_1968
# Annotation/n02108551-Tibetan_mastiff/n02108551_1991
# Annotation/n02108551-Tibetan_mastiff/n02108551_2000
# Annotation/n02108551-Tibetan_mastiff/n02108551_2014
# Annotation/n02108551-Tibetan_mastiff/n02108551_2025
# Annotation/n02108551-Tibetan_mastiff/n02108551_2097
# Annotation/n02108551-Tibetan_mastiff/n02108551_211
# Annotation/n02108551-Tibetan_mastiff/n02108551_2111
# Annotation/n02108551-Tibetan_mastiff/n02108551_2122
# Annotation/n02108551-Tibetan_mastiff/n02108551_2240
# Annotation/n02108551-Tibetan_mastiff/n02108551_226
# Annotation/n02108551-Tibetan_mastiff/n02108551_227
# Annotation/n02108551-Tibetan_mastiff/n02108551_2301
# Annotation/n02108551-Tibetan_mastiff/n02108551_232
# Annotation/n02108551-Tibetan_mastiff/n02108551_2326
# Annotation/n02108551-Tibetan_mastiff/n02108551_239
# Annotation/n02108551-Tibetan_mastiff/n02108551_240
# Annotation/n02108551-Tibetan_mastiff/n02108551_246
# Annotation/n02108551-Tibetan_mastiff/n02108551_2514
# Annotation/n02108551-Tibetan_mastiff/n02108551_2550
# Annotation/n02108551-Tibetan_mastiff/n02108551_2596
# Annotation/n02108551-Tibetan_mastiff/n02108551_2611
# Annotation/n02108551-Tibetan_mastiff/n02108551_262
# Annotation/n02108551-Tibetan_mastiff/n02108551_2658
# Annotation/n02108551-Tibetan_mastiff/n02108551_2667
# Annotation/n02108551-Tibetan_mastiff/n02108551_2698
# Annotation/n02108551-Tibetan_mastiff/n02108551_2778
# Annotation/n02108551-Tibetan_mastiff/n02108551_2836
# Annotation/n02108551-Tibetan_mastiff/n02108551_2850
# Annotation/n02108551-Tibetan_mastiff/n02108551_2861
# Annotation/n02108551-Tibetan_mastiff/n02108551_2898
# Annotation/n02108551-Tibetan_mastiff/n02108551_290
# Annotation/n02108551-Tibetan_mastiff/n02108551_2921
# Annotation/n02108551-Tibetan_mastiff/n02108551_2948
# Annotation/n02108551-Tibetan_mastiff/n02108551_3147
# Annotation/n02108551-Tibetan_mastiff/n02108551_3222
# Annotation/n02108551-Tibetan_mastiff/n02108551_3284
# Annotation/n02108551-Tibetan_mastiff/n02108551_3305
# Annotation/n02108551-Tibetan_mastiff/n02108551_340
# Annotation/n02108551-Tibetan_mastiff/n02108551_3482
# Annotation/n02108551-Tibetan_mastiff/n02108551_3501
# Annotation/n02108551-Tibetan_mastiff/n02108551_351
# Annotation/n02108551-Tibetan_mastiff/n02108551_3522
# Annotation/n02108551-Tibetan_mastiff/n02108551_3578
# Annotation/n02108551-Tibetan_mastiff/n02108551_3662
# Annotation/n02108551-Tibetan_mastiff/n02108551_369
# Annotation/n02108551-Tibetan_mastiff/n02108551_3737
# Annotation/n02108551-Tibetan_mastiff/n02108551_3814
# Annotation/n02108551-Tibetan_mastiff/n02108551_3840
# Annotation/n02108551-Tibetan_mastiff/n02108551_3980
# Annotation/n02108551-Tibetan_mastiff/n02108551_4236
# Annotation/n02108551-Tibetan_mastiff/n02108551_4284
# Annotation/n02108551-Tibetan_mastiff/n02108551_4286
# Annotation/n02108551-Tibetan_mastiff/n02108551_4309
# Annotation/n02108551-Tibetan_mastiff/n02108551_4310
# Annotation/n02108551-Tibetan_mastiff/n02108551_433
# Annotation/n02108551-Tibetan_mastiff/n02108551_4340
# Annotation/n02108551-Tibetan_mastiff/n02108551_4341
# Annotation/n02108551-Tibetan_mastiff/n02108551_4379
# Annotation/n02108551-Tibetan_mastiff/n02108551_4392
# Annotation/n02108551-Tibetan_mastiff/n02108551_441
# Annotation/n02108551-Tibetan_mastiff/n02108551_4421
# Annotation/n02108551-Tibetan_mastiff/n02108551_4426
# Annotation/n02108551-Tibetan_mastiff/n02108551_4507
# Annotation/n02108551-Tibetan_mastiff/n02108551_462
# Annotation/n02108551-Tibetan_mastiff/n02108551_4682
# Annotation/n02108551-Tibetan_mastiff/n02108551_4697
# Annotation/n02108551-Tibetan_mastiff/n02108551_4698
# Annotation/n02108551-Tibetan_mastiff/n02108551_4751
# Annotation/n02108551-Tibetan_mastiff/n02108551_4769
# Annotation/n02108551-Tibetan_mastiff/n02108551_4790
# Annotation/n02108551-Tibetan_mastiff/n02108551_4807
# Annotation/n02108551-Tibetan_mastiff/n02108551_4820
# Annotation/n02108551-Tibetan_mastiff/n02108551_4918
# Annotation/n02108551-Tibetan_mastiff/n02108551_4927
# Annotation/n02108551-Tibetan_mastiff/n02108551_5004
# Annotation/n02108551-Tibetan_mastiff/n02108551_5050
# Annotation/n02108551-Tibetan_mastiff/n02108551_5216
# Annotation/n02108551-Tibetan_mastiff/n02108551_5540
# Annotation/n02108551-Tibetan_mastiff/n02108551_5547
# Annotation/n02108551-Tibetan_mastiff/n02108551_5625
# Annotation/n02108551-Tibetan_mastiff/n02108551_5682
# Annotation/n02108551-Tibetan_mastiff/n02108551_572
# Annotation/n02108551-Tibetan_mastiff/n02108551_581
# Annotation/n02108551-Tibetan_mastiff/n02108551_5830
# Annotation/n02108551-Tibetan_mastiff/n02108551_598
# Annotation/n02108551-Tibetan_mastiff/n02108551_6100
# Annotation/n02108551-Tibetan_mastiff/n02108551_6179
# Annotation/n02108551-Tibetan_mastiff/n02108551_6295
# Annotation/n02108551-Tibetan_mastiff/n02108551_634
# Annotation/n02108551-Tibetan_mastiff/n02108551_640
# Annotation/n02108551-Tibetan_mastiff/n02108551_650
# Annotation/n02108551-Tibetan_mastiff/n02108551_658
# Annotation/n02108551-Tibetan_mastiff/n02108551_660
# Annotation/n02108551-Tibetan_mastiff/n02108551_668
# Annotation/n02108551-Tibetan_mastiff/n02108551_728
# Annotation/n02108551-Tibetan_mastiff/n02108551_734
# Annotation/n02108551-Tibetan_mastiff/n02108551_7523
# Annotation/n02108551-Tibetan_mastiff/n02108551_7788
# Annotation/n02108551-Tibetan_mastiff/n02108551_786
# Annotation/n02108551-Tibetan_mastiff/n02108551_810
# Annotation/n02108551-Tibetan_mastiff/n02108551_832
# Annotation/n02108551-Tibetan_mastiff/n02108551_8370
# Annotation/n02108551-Tibetan_mastiff/n02108551_854
# Annotation/n02108551-Tibetan_mastiff/n02108551_8943
# Annotation/n02108551-Tibetan_mastiff/n02108551_899
# Annotation/n02108551-Tibetan_mastiff/n02108551_902
# Annotation/n02108551-Tibetan_mastiff/n02108551_9132
# Annotation/n02108551-Tibetan_mastiff/n02108551_9391
# Annotation/n02108551-Tibetan_mastiff/n02108551_957
# Annotation/n02108551-Tibetan_mastiff/n02108551_9622
# Annotation/n02108551-Tibetan_mastiff/n02108551_968
# Annotation/n02108551-Tibetan_mastiff/n02108551_978
# Annotation/n02108551-Tibetan_mastiff/n02108551_9913
# Annotation/n02108915-French_bulldog/
# Annotation/n02108915-French_bulldog/n02108915_10204
# Annotation/n02108915-French_bulldog/n02108915_10564
# Annotation/n02108915-French_bulldog/n02108915_110
# Annotation/n02108915-French_bulldog/n02108915_1114
# Annotation/n02108915-French_bulldog/n02108915_1119
# Annotation/n02108915-French_bulldog/n02108915_11207
# Annotation/n02108915-French_bulldog/n02108915_11220
# Annotation/n02108915-French_bulldog/n02108915_11327
# Annotation/n02108915-French_bulldog/n02108915_11335
# Annotation/n02108915-French_bulldog/n02108915_1137
# Annotation/n02108915-French_bulldog/n02108915_11498
# Annotation/n02108915-French_bulldog/n02108915_11550
# Annotation/n02108915-French_bulldog/n02108915_11653
# Annotation/n02108915-French_bulldog/n02108915_1188
# Annotation/n02108915-French_bulldog/n02108915_12139
# Annotation/n02108915-French_bulldog/n02108915_12288
# Annotation/n02108915-French_bulldog/n02108915_12317
# Annotation/n02108915-French_bulldog/n02108915_12319
# Annotation/n02108915-French_bulldog/n02108915_12460
# Annotation/n02108915-French_bulldog/n02108915_12618
# Annotation/n02108915-French_bulldog/n02108915_12904
# Annotation/n02108915-French_bulldog/n02108915_1343
# Annotation/n02108915-French_bulldog/n02108915_142
# Annotation/n02108915-French_bulldog/n02108915_1465
# Annotation/n02108915-French_bulldog/n02108915_1513
# Annotation/n02108915-French_bulldog/n02108915_160
# Annotation/n02108915-French_bulldog/n02108915_1612
# Annotation/n02108915-French_bulldog/n02108915_1752
# Annotation/n02108915-French_bulldog/n02108915_1788
# Annotation/n02108915-French_bulldog/n02108915_1839
# Annotation/n02108915-French_bulldog/n02108915_1866
# Annotation/n02108915-French_bulldog/n02108915_1871
# Annotation/n02108915-French_bulldog/n02108915_1895
# Annotation/n02108915-French_bulldog/n02108915_1911
# Annotation/n02108915-French_bulldog/n02108915_1958
# Annotation/n02108915-French_bulldog/n02108915_198
# Annotation/n02108915-French_bulldog/n02108915_2118
# Annotation/n02108915-French_bulldog/n02108915_2166
# Annotation/n02108915-French_bulldog/n02108915_225
# Annotation/n02108915-French_bulldog/n02108915_2279
# Annotation/n02108915-French_bulldog/n02108915_2307
# Annotation/n02108915-French_bulldog/n02108915_2312
# Annotation/n02108915-French_bulldog/n02108915_2326
# Annotation/n02108915-French_bulldog/n02108915_2380
# Annotation/n02108915-French_bulldog/n02108915_2391
# Annotation/n02108915-French_bulldog/n02108915_2514
# Annotation/n02108915-French_bulldog/n02108915_2545
# Annotation/n02108915-French_bulldog/n02108915_2570
# Annotation/n02108915-French_bulldog/n02108915_2603
# Annotation/n02108915-French_bulldog/n02108915_2681
# Annotation/n02108915-French_bulldog/n02108915_2756
# Annotation/n02108915-French_bulldog/n02108915_2807
# Annotation/n02108915-French_bulldog/n02108915_2835
# Annotation/n02108915-French_bulldog/n02108915_2899
# Annotation/n02108915-French_bulldog/n02108915_2926
# Annotation/n02108915-French_bulldog/n02108915_2946
# Annotation/n02108915-French_bulldog/n02108915_2980
# Annotation/n02108915-French_bulldog/n02108915_3083
# Annotation/n02108915-French_bulldog/n02108915_3098
# Annotation/n02108915-French_bulldog/n02108915_3104
# Annotation/n02108915-French_bulldog/n02108915_311
# Annotation/n02108915-French_bulldog/n02108915_3129
# Annotation/n02108915-French_bulldog/n02108915_3140
# Annotation/n02108915-French_bulldog/n02108915_3153
# Annotation/n02108915-French_bulldog/n02108915_3184
# Annotation/n02108915-French_bulldog/n02108915_3202
# Annotation/n02108915-French_bulldog/n02108915_3219
# Annotation/n02108915-French_bulldog/n02108915_3258
# Annotation/n02108915-French_bulldog/n02108915_3266
# Annotation/n02108915-French_bulldog/n02108915_328
# Annotation/n02108915-French_bulldog/n02108915_3300
# Annotation/n02108915-French_bulldog/n02108915_3346
# Annotation/n02108915-French_bulldog/n02108915_3369
# Annotation/n02108915-French_bulldog/n02108915_3382
# Annotation/n02108915-French_bulldog/n02108915_3398
# Annotation/n02108915-French_bulldog/n02108915_341
# Annotation/n02108915-French_bulldog/n02108915_3464
# Annotation/n02108915-French_bulldog/n02108915_350
# Annotation/n02108915-French_bulldog/n02108915_3520
# Annotation/n02108915-French_bulldog/n02108915_3527
# Annotation/n02108915-French_bulldog/n02108915_3544
# Annotation/n02108915-French_bulldog/n02108915_3557
# Annotation/n02108915-French_bulldog/n02108915_3575
# Annotation/n02108915-French_bulldog/n02108915_3640
# Annotation/n02108915-French_bulldog/n02108915_3665
# Annotation/n02108915-French_bulldog/n02108915_3702
# Annotation/n02108915-French_bulldog/n02108915_3766
# Annotation/n02108915-French_bulldog/n02108915_38
# Annotation/n02108915-French_bulldog/n02108915_3880
# Annotation/n02108915-French_bulldog/n02108915_3913
# Annotation/n02108915-French_bulldog/n02108915_3988
# Annotation/n02108915-French_bulldog/n02108915_4066
# Annotation/n02108915-French_bulldog/n02108915_4133
# Annotation/n02108915-French_bulldog/n02108915_4160
# Annotation/n02108915-French_bulldog/n02108915_4176
# Annotation/n02108915-French_bulldog/n02108915_4193
# Annotation/n02108915-French_bulldog/n02108915_4214
# Annotation/n02108915-French_bulldog/n02108915_4303
# Annotation/n02108915-French_bulldog/n02108915_4372
# Annotation/n02108915-French_bulldog/n02108915_4474
# Annotation/n02108915-French_bulldog/n02108915_4477
# Annotation/n02108915-French_bulldog/n02108915_4500
# Annotation/n02108915-French_bulldog/n02108915_4603
# Annotation/n02108915-French_bulldog/n02108915_4731
# Annotation/n02108915-French_bulldog/n02108915_4776
# Annotation/n02108915-French_bulldog/n02108915_481
# Annotation/n02108915-French_bulldog/n02108915_4860
# Annotation/n02108915-French_bulldog/n02108915_4901
# Annotation/n02108915-French_bulldog/n02108915_4991
# Annotation/n02108915-French_bulldog/n02108915_5087
# Annotation/n02108915-French_bulldog/n02108915_5096
# Annotation/n02108915-French_bulldog/n02108915_5201
# Annotation/n02108915-French_bulldog/n02108915_5306
# Annotation/n02108915-French_bulldog/n02108915_5319
# Annotation/n02108915-French_bulldog/n02108915_5337
# Annotation/n02108915-French_bulldog/n02108915_5367
# Annotation/n02108915-French_bulldog/n02108915_5458
# Annotation/n02108915-French_bulldog/n02108915_553
# Annotation/n02108915-French_bulldog/n02108915_5596
# Annotation/n02108915-French_bulldog/n02108915_5667
# Annotation/n02108915-French_bulldog/n02108915_5669
# Annotation/n02108915-French_bulldog/n02108915_57
# Annotation/n02108915-French_bulldog/n02108915_571
# Annotation/n02108915-French_bulldog/n02108915_5813
# Annotation/n02108915-French_bulldog/n02108915_6008
# Annotation/n02108915-French_bulldog/n02108915_6142
# Annotation/n02108915-French_bulldog/n02108915_618
# Annotation/n02108915-French_bulldog/n02108915_623
# Annotation/n02108915-French_bulldog/n02108915_6270
# Annotation/n02108915-French_bulldog/n02108915_644
# Annotation/n02108915-French_bulldog/n02108915_6462
# Annotation/n02108915-French_bulldog/n02108915_6521
# Annotation/n02108915-French_bulldog/n02108915_653
# Annotation/n02108915-French_bulldog/n02108915_656
# Annotation/n02108915-French_bulldog/n02108915_696
# Annotation/n02108915-French_bulldog/n02108915_7115
# Annotation/n02108915-French_bulldog/n02108915_716
# Annotation/n02108915-French_bulldog/n02108915_720
# Annotation/n02108915-French_bulldog/n02108915_7266
# Annotation/n02108915-French_bulldog/n02108915_759
# Annotation/n02108915-French_bulldog/n02108915_7608
# Annotation/n02108915-French_bulldog/n02108915_7806
# Annotation/n02108915-French_bulldog/n02108915_7883
# Annotation/n02108915-French_bulldog/n02108915_8258
# Annotation/n02108915-French_bulldog/n02108915_8425
# Annotation/n02108915-French_bulldog/n02108915_8604
# Annotation/n02108915-French_bulldog/n02108915_8696
# Annotation/n02108915-French_bulldog/n02108915_8923
# Annotation/n02108915-French_bulldog/n02108915_895
# Annotation/n02108915-French_bulldog/n02108915_9125
# Annotation/n02108915-French_bulldog/n02108915_9202
# Annotation/n02108915-French_bulldog/n02108915_9399
# Annotation/n02108915-French_bulldog/n02108915_9457
# Annotation/n02108915-French_bulldog/n02108915_9530
# Annotation/n02108915-French_bulldog/n02108915_9666
# Annotation/n02108915-French_bulldog/n02108915_971
# Annotation/n02108915-French_bulldog/n02108915_977
# Annotation/n02108915-French_bulldog/n02108915_9804
# Annotation/n02108915-French_bulldog/n02108915_9899
# Annotation/n02109047-Great_Dane/
# Annotation/n02109047-Great_Dane/n02109047_1005
# Annotation/n02109047-Great_Dane/n02109047_10112
# Annotation/n02109047-Great_Dane/n02109047_10160
# Annotation/n02109047-Great_Dane/n02109047_10414
# Annotation/n02109047-Great_Dane/n02109047_11178
# Annotation/n02109047-Great_Dane/n02109047_11184
# Annotation/n02109047-Great_Dane/n02109047_11472
# Annotation/n02109047-Great_Dane/n02109047_12085
# Annotation/n02109047-Great_Dane/n02109047_12193
# Annotation/n02109047-Great_Dane/n02109047_12467
# Annotation/n02109047-Great_Dane/n02109047_12569
# Annotation/n02109047-Great_Dane/n02109047_1260
# Annotation/n02109047-Great_Dane/n02109047_12678
# Annotation/n02109047-Great_Dane/n02109047_12726
# Annotation/n02109047-Great_Dane/n02109047_1284
# Annotation/n02109047-Great_Dane/n02109047_12899
# Annotation/n02109047-Great_Dane/n02109047_12916
# Annotation/n02109047-Great_Dane/n02109047_12966
# Annotation/n02109047-Great_Dane/n02109047_13016
# Annotation/n02109047-Great_Dane/n02109047_13040
# Annotation/n02109047-Great_Dane/n02109047_13072
# Annotation/n02109047-Great_Dane/n02109047_13211
# Annotation/n02109047-Great_Dane/n02109047_1371
# Annotation/n02109047-Great_Dane/n02109047_13730
# Annotation/n02109047-Great_Dane/n02109047_13744
# Annotation/n02109047-Great_Dane/n02109047_13868
# Annotation/n02109047-Great_Dane/n02109047_13977
# Annotation/n02109047-Great_Dane/n02109047_14013
# Annotation/n02109047-Great_Dane/n02109047_1449
# Annotation/n02109047-Great_Dane/n02109047_1480
# Annotation/n02109047-Great_Dane/n02109047_1533
# Annotation/n02109047-Great_Dane/n02109047_1659
# Annotation/n02109047-Great_Dane/n02109047_1672
# Annotation/n02109047-Great_Dane/n02109047_16735
# Annotation/n02109047-Great_Dane/n02109047_17050
# Annotation/n02109047-Great_Dane/n02109047_17629
# Annotation/n02109047-Great_Dane/n02109047_17874
# Annotation/n02109047-Great_Dane/n02109047_1813
# Annotation/n02109047-Great_Dane/n02109047_18490
# Annotation/n02109047-Great_Dane/n02109047_18614
# Annotation/n02109047-Great_Dane/n02109047_1876
# Annotation/n02109047-Great_Dane/n02109047_19775
# Annotation/n02109047-Great_Dane/n02109047_19984
# Annotation/n02109047-Great_Dane/n02109047_20023
# Annotation/n02109047-Great_Dane/n02109047_2009
# Annotation/n02109047-Great_Dane/n02109047_20229
# Annotation/n02109047-Great_Dane/n02109047_2072
# Annotation/n02109047-Great_Dane/n02109047_20770
# Annotation/n02109047-Great_Dane/n02109047_21567
# Annotation/n02109047-Great_Dane/n02109047_21589
# Annotation/n02109047-Great_Dane/n02109047_21692
# Annotation/n02109047-Great_Dane/n02109047_21903
# Annotation/n02109047-Great_Dane/n02109047_22006
# Annotation/n02109047-Great_Dane/n02109047_22193
# Annotation/n02109047-Great_Dane/n02109047_22413
# Annotation/n02109047-Great_Dane/n02109047_2248
# Annotation/n02109047-Great_Dane/n02109047_22481
# Annotation/n02109047-Great_Dane/n02109047_22955
# Annotation/n02109047-Great_Dane/n02109047_23058
# Annotation/n02109047-Great_Dane/n02109047_23483
# Annotation/n02109047-Great_Dane/n02109047_2358
# Annotation/n02109047-Great_Dane/n02109047_23814
# Annotation/n02109047-Great_Dane/n02109047_23852
# Annotation/n02109047-Great_Dane/n02109047_24258
# Annotation/n02109047-Great_Dane/n02109047_24340
# Annotation/n02109047-Great_Dane/n02109047_2465
# Annotation/n02109047-Great_Dane/n02109047_24710
# Annotation/n02109047-Great_Dane/n02109047_2475
# Annotation/n02109047-Great_Dane/n02109047_24773
# Annotation/n02109047-Great_Dane/n02109047_2527
# Annotation/n02109047-Great_Dane/n02109047_25277
# Annotation/n02109047-Great_Dane/n02109047_25291
# Annotation/n02109047-Great_Dane/n02109047_25342
# Annotation/n02109047-Great_Dane/n02109047_2553
# Annotation/n02109047-Great_Dane/n02109047_25603
# Annotation/n02109047-Great_Dane/n02109047_25719
# Annotation/n02109047-Great_Dane/n02109047_25779
# Annotation/n02109047-Great_Dane/n02109047_26134
# Annotation/n02109047-Great_Dane/n02109047_2630
# Annotation/n02109047-Great_Dane/n02109047_26729
# Annotation/n02109047-Great_Dane/n02109047_26860
# Annotation/n02109047-Great_Dane/n02109047_27131
# Annotation/n02109047-Great_Dane/n02109047_27409
# Annotation/n02109047-Great_Dane/n02109047_27476
# Annotation/n02109047-Great_Dane/n02109047_2810
# Annotation/n02109047-Great_Dane/n02109047_282
# Annotation/n02109047-Great_Dane/n02109047_28208
# Annotation/n02109047-Great_Dane/n02109047_28433
# Annotation/n02109047-Great_Dane/n02109047_2851
# Annotation/n02109047-Great_Dane/n02109047_2859
# Annotation/n02109047-Great_Dane/n02109047_3001
# Annotation/n02109047-Great_Dane/n02109047_30923
# Annotation/n02109047-Great_Dane/n02109047_31049
# Annotation/n02109047-Great_Dane/n02109047_31117
# Annotation/n02109047-Great_Dane/n02109047_31274
# Annotation/n02109047-Great_Dane/n02109047_31376
# Annotation/n02109047-Great_Dane/n02109047_31522
# Annotation/n02109047-Great_Dane/n02109047_31830
# Annotation/n02109047-Great_Dane/n02109047_32010
# Annotation/n02109047-Great_Dane/n02109047_32635
# Annotation/n02109047-Great_Dane/n02109047_32692
# Annotation/n02109047-Great_Dane/n02109047_33029
# Annotation/n02109047-Great_Dane/n02109047_33047
# Annotation/n02109047-Great_Dane/n02109047_33588
# Annotation/n02109047-Great_Dane/n02109047_33651
# Annotation/n02109047-Great_Dane/n02109047_34022
# Annotation/n02109047-Great_Dane/n02109047_34093
# Annotation/n02109047-Great_Dane/n02109047_34102
# Annotation/n02109047-Great_Dane/n02109047_34148
# Annotation/n02109047-Great_Dane/n02109047_34162
# Annotation/n02109047-Great_Dane/n02109047_34175
# Annotation/n02109047-Great_Dane/n02109047_34209
# Annotation/n02109047-Great_Dane/n02109047_3643
# Annotation/n02109047-Great_Dane/n02109047_4267
# Annotation/n02109047-Great_Dane/n02109047_481
# Annotation/n02109047-Great_Dane/n02109047_4884
# Annotation/n02109047-Great_Dane/n02109047_5005
# Annotation/n02109047-Great_Dane/n02109047_5181
# Annotation/n02109047-Great_Dane/n02109047_5326
# Annotation/n02109047-Great_Dane/n02109047_5331
# Annotation/n02109047-Great_Dane/n02109047_5573
# Annotation/n02109047-Great_Dane/n02109047_5588
# Annotation/n02109047-Great_Dane/n02109047_5618
# Annotation/n02109047-Great_Dane/n02109047_562
# Annotation/n02109047-Great_Dane/n02109047_5675
# Annotation/n02109047-Great_Dane/n02109047_5822
# Annotation/n02109047-Great_Dane/n02109047_5894
# Annotation/n02109047-Great_Dane/n02109047_5910
# Annotation/n02109047-Great_Dane/n02109047_5936
# Annotation/n02109047-Great_Dane/n02109047_6008
# Annotation/n02109047-Great_Dane/n02109047_6042
# Annotation/n02109047-Great_Dane/n02109047_6061
# Annotation/n02109047-Great_Dane/n02109047_6093
# Annotation/n02109047-Great_Dane/n02109047_6265
# Annotation/n02109047-Great_Dane/n02109047_6276
# Annotation/n02109047-Great_Dane/n02109047_638
# Annotation/n02109047-Great_Dane/n02109047_6447
# Annotation/n02109047-Great_Dane/n02109047_6680
# Annotation/n02109047-Great_Dane/n02109047_7072
# Annotation/n02109047-Great_Dane/n02109047_7156
# Annotation/n02109047-Great_Dane/n02109047_7227
# Annotation/n02109047-Great_Dane/n02109047_744
# Annotation/n02109047-Great_Dane/n02109047_8090
# Annotation/n02109047-Great_Dane/n02109047_8139
# Annotation/n02109047-Great_Dane/n02109047_875
# Annotation/n02109047-Great_Dane/n02109047_888
# Annotation/n02109047-Great_Dane/n02109047_8912
# Annotation/n02109047-Great_Dane/n02109047_906
# Annotation/n02109047-Great_Dane/n02109047_9164
# Annotation/n02109047-Great_Dane/n02109047_926
# Annotation/n02109047-Great_Dane/n02109047_9396
# Annotation/n02109047-Great_Dane/n02109047_94
# Annotation/n02109047-Great_Dane/n02109047_941
# Annotation/n02109047-Great_Dane/n02109047_946
# Annotation/n02109047-Great_Dane/n02109047_9503
# Annotation/n02109047-Great_Dane/n02109047_9604
# Annotation/n02109525-Saint_Bernard/
# Annotation/n02109525-Saint_Bernard/n02109525_10146
# Annotation/n02109525-Saint_Bernard/n02109525_10215
# Annotation/n02109525-Saint_Bernard/n02109525_10297
# Annotation/n02109525-Saint_Bernard/n02109525_10417
# Annotation/n02109525-Saint_Bernard/n02109525_10545
# Annotation/n02109525-Saint_Bernard/n02109525_10743
# Annotation/n02109525-Saint_Bernard/n02109525_10792
# Annotation/n02109525-Saint_Bernard/n02109525_10805
# Annotation/n02109525-Saint_Bernard/n02109525_10992
# Annotation/n02109525-Saint_Bernard/n02109525_1100
# Annotation/n02109525-Saint_Bernard/n02109525_11274
# Annotation/n02109525-Saint_Bernard/n02109525_11465
# Annotation/n02109525-Saint_Bernard/n02109525_11747
# Annotation/n02109525-Saint_Bernard/n02109525_12041
# Annotation/n02109525-Saint_Bernard/n02109525_12155
# Annotation/n02109525-Saint_Bernard/n02109525_12272
# Annotation/n02109525-Saint_Bernard/n02109525_12392
# Annotation/n02109525-Saint_Bernard/n02109525_12610
# Annotation/n02109525-Saint_Bernard/n02109525_1271
# Annotation/n02109525-Saint_Bernard/n02109525_13356
# Annotation/n02109525-Saint_Bernard/n02109525_13702
# Annotation/n02109525-Saint_Bernard/n02109525_13812
# Annotation/n02109525-Saint_Bernard/n02109525_13906
# Annotation/n02109525-Saint_Bernard/n02109525_14249
# Annotation/n02109525-Saint_Bernard/n02109525_14676
# Annotation/n02109525-Saint_Bernard/n02109525_14774
# Annotation/n02109525-Saint_Bernard/n02109525_1480
# Annotation/n02109525-Saint_Bernard/n02109525_1502
# Annotation/n02109525-Saint_Bernard/n02109525_15029
# Annotation/n02109525-Saint_Bernard/n02109525_15376
# Annotation/n02109525-Saint_Bernard/n02109525_15506
# Annotation/n02109525-Saint_Bernard/n02109525_15579
# Annotation/n02109525-Saint_Bernard/n02109525_15746
# Annotation/n02109525-Saint_Bernard/n02109525_1575
# Annotation/n02109525-Saint_Bernard/n02109525_16215
# Annotation/n02109525-Saint_Bernard/n02109525_1624
# Annotation/n02109525-Saint_Bernard/n02109525_16284
# Annotation/n02109525-Saint_Bernard/n02109525_16487
# Annotation/n02109525-Saint_Bernard/n02109525_17025
# Annotation/n02109525-Saint_Bernard/n02109525_1717
# Annotation/n02109525-Saint_Bernard/n02109525_17182
# Annotation/n02109525-Saint_Bernard/n02109525_17291
# Annotation/n02109525-Saint_Bernard/n02109525_18371
# Annotation/n02109525-Saint_Bernard/n02109525_1843
# Annotation/n02109525-Saint_Bernard/n02109525_1864
# Annotation/n02109525-Saint_Bernard/n02109525_18685
# Annotation/n02109525-Saint_Bernard/n02109525_1972
# Annotation/n02109525-Saint_Bernard/n02109525_2008
# Annotation/n02109525-Saint_Bernard/n02109525_2035
# Annotation/n02109525-Saint_Bernard/n02109525_2369
# Annotation/n02109525-Saint_Bernard/n02109525_2575
# Annotation/n02109525-Saint_Bernard/n02109525_2648
# Annotation/n02109525-Saint_Bernard/n02109525_2681
# Annotation/n02109525-Saint_Bernard/n02109525_2737
# Annotation/n02109525-Saint_Bernard/n02109525_2770
# Annotation/n02109525-Saint_Bernard/n02109525_2810
# Annotation/n02109525-Saint_Bernard/n02109525_3346
# Annotation/n02109525-Saint_Bernard/n02109525_3360
# Annotation/n02109525-Saint_Bernard/n02109525_345
# Annotation/n02109525-Saint_Bernard/n02109525_3506
# Annotation/n02109525-Saint_Bernard/n02109525_3531
# Annotation/n02109525-Saint_Bernard/n02109525_3667
# Annotation/n02109525-Saint_Bernard/n02109525_370
# Annotation/n02109525-Saint_Bernard/n02109525_393
# Annotation/n02109525-Saint_Bernard/n02109525_4021
# Annotation/n02109525-Saint_Bernard/n02109525_4308
# Annotation/n02109525-Saint_Bernard/n02109525_499
# Annotation/n02109525-Saint_Bernard/n02109525_5007
# Annotation/n02109525-Saint_Bernard/n02109525_5264
# Annotation/n02109525-Saint_Bernard/n02109525_5385
# Annotation/n02109525-Saint_Bernard/n02109525_6215
# Annotation/n02109525-Saint_Bernard/n02109525_7024
# Annotation/n02109525-Saint_Bernard/n02109525_7085
# Annotation/n02109525-Saint_Bernard/n02109525_7497
# Annotation/n02109525-Saint_Bernard/n02109525_7656
# Annotation/n02109525-Saint_Bernard/n02109525_7982
# Annotation/n02109525-Saint_Bernard/n02109525_8312
# Annotation/n02109525-Saint_Bernard/n02109525_883
# Annotation/n02109525-Saint_Bernard/n02109525_9345
# Annotation/n02109525-Saint_Bernard/n02109525_9379
# Annotation/n02109525-Saint_Bernard/n02109525_9426
# Annotation/n02109525-Saint_Bernard/n02109525_9522
# Annotation/n02109525-Saint_Bernard/n02109525_9869
# Annotation/n02109525-Saint_Bernard/n02109525_9872
# Annotation/n02109525-Saint_Bernard/n02109525_997
# Annotation/n02109525-Saint_Bernard/n02109525_18136
# Annotation/n02109525-Saint_Bernard/n02109525_1314
# Annotation/n02109525-Saint_Bernard/n02109525_7121
# Annotation/n02109525-Saint_Bernard/n02109525_950
# Annotation/n02109525-Saint_Bernard/n02109525_11444
# Annotation/n02109525-Saint_Bernard/n02109525_13794
# Annotation/n02109525-Saint_Bernard/n02109525_11285
# Annotation/n02109525-Saint_Bernard/n02109525_11445
# Annotation/n02109525-Saint_Bernard/n02109525_3388
# Annotation/n02109525-Saint_Bernard/n02109525_10321
# Annotation/n02109525-Saint_Bernard/n02109525_13420
# Annotation/n02109525-Saint_Bernard/n02109525_8545
# Annotation/n02109525-Saint_Bernard/n02109525_13780
# Annotation/n02109525-Saint_Bernard/n02109525_2943
# Annotation/n02109525-Saint_Bernard/n02109525_11155
# Annotation/n02109525-Saint_Bernard/n02109525_12736
# Annotation/n02109525-Saint_Bernard/n02109525_6593
# Annotation/n02109525-Saint_Bernard/n02109525_823
# Annotation/n02109525-Saint_Bernard/n02109525_16100
# Annotation/n02109525-Saint_Bernard/n02109525_368
# Annotation/n02109525-Saint_Bernard/n02109525_3448
# Annotation/n02109525-Saint_Bernard/n02109525_16981
# Annotation/n02109525-Saint_Bernard/n02109525_10332
# Annotation/n02109525-Saint_Bernard/n02109525_13580
# Annotation/n02109525-Saint_Bernard/n02109525_11452
# Annotation/n02109525-Saint_Bernard/n02109525_2840
# Annotation/n02109525-Saint_Bernard/n02109525_2248
# Annotation/n02109525-Saint_Bernard/n02109525_9130
# Annotation/n02109525-Saint_Bernard/n02109525_14297
# Annotation/n02109525-Saint_Bernard/n02109525_751
# Annotation/n02109525-Saint_Bernard/n02109525_539
# Annotation/n02109525-Saint_Bernard/n02109525_7336
# Annotation/n02109525-Saint_Bernard/n02109525_11732
# Annotation/n02109525-Saint_Bernard/n02109525_12937
# Annotation/n02109525-Saint_Bernard/n02109525_13655
# Annotation/n02109525-Saint_Bernard/n02109525_1880
# Annotation/n02109525-Saint_Bernard/n02109525_13154
# Annotation/n02109525-Saint_Bernard/n02109525_7444
# Annotation/n02109525-Saint_Bernard/n02109525_16485
# Annotation/n02109525-Saint_Bernard/n02109525_8475
# Annotation/n02109525-Saint_Bernard/n02109525_5966
# Annotation/n02109525-Saint_Bernard/n02109525_10446
# Annotation/n02109525-Saint_Bernard/n02109525_4516
# Annotation/n02109525-Saint_Bernard/n02109525_7109
# Annotation/n02109525-Saint_Bernard/n02109525_13988
# Annotation/n02109525-Saint_Bernard/n02109525_14198
# Annotation/n02109525-Saint_Bernard/n02109525_10063
# Annotation/n02109525-Saint_Bernard/n02109525_10960
# Annotation/n02109525-Saint_Bernard/n02109525_6931
# Annotation/n02109525-Saint_Bernard/n02109525_10032
# Annotation/n02109525-Saint_Bernard/n02109525_5498
# Annotation/n02109525-Saint_Bernard/n02109525_13627
# Annotation/n02109525-Saint_Bernard/n02109525_12604
# Annotation/n02109525-Saint_Bernard/n02109525_8822
# Annotation/n02109525-Saint_Bernard/n02109525_8211
# Annotation/n02109525-Saint_Bernard/n02109525_2385
# Annotation/n02109525-Saint_Bernard/n02109525_8704
# Annotation/n02109525-Saint_Bernard/n02109525_8417
# Annotation/n02109525-Saint_Bernard/n02109525_1741
# Annotation/n02109525-Saint_Bernard/n02109525_14999
# Annotation/n02109525-Saint_Bernard/n02109525_13230
# Annotation/n02109525-Saint_Bernard/n02109525_18948
# Annotation/n02109525-Saint_Bernard/n02109525_10908
# Annotation/n02109525-Saint_Bernard/n02109525_243
# Annotation/n02109525-Saint_Bernard/n02109525_1902
# Annotation/n02109525-Saint_Bernard/n02109525_9243
# Annotation/n02109525-Saint_Bernard/n02109525_444
# Annotation/n02109525-Saint_Bernard/n02109525_523
# Annotation/n02109525-Saint_Bernard/n02109525_13410
# Annotation/n02109525-Saint_Bernard/n02109525_12641
# Annotation/n02109525-Saint_Bernard/n02109525_2104
# Annotation/n02109525-Saint_Bernard/n02109525_7579
# Annotation/n02109525-Saint_Bernard/n02109525_5013
# Annotation/n02109525-Saint_Bernard/n02109525_12875
# Annotation/n02109525-Saint_Bernard/n02109525_10251
# Annotation/n02109525-Saint_Bernard/n02109525_7016
# Annotation/n02109525-Saint_Bernard/n02109525_13146
# Annotation/n02109525-Saint_Bernard/n02109525_17140
# Annotation/n02109525-Saint_Bernard/n02109525_10374
# Annotation/n02109525-Saint_Bernard/n02109525_6663
# Annotation/n02109525-Saint_Bernard/n02109525_6019
# Annotation/n02109525-Saint_Bernard/n02109525_13804
# Annotation/n02109525-Saint_Bernard/n02109525_16346
# Annotation/n02109525-Saint_Bernard/n02109525_6693
# Annotation/n02109525-Saint_Bernard/n02109525_8096
# Annotation/n02109961-Eskimo_dog/
# Annotation/n02109961-Eskimo_dog/n02109961_10021
# Annotation/n02109961-Eskimo_dog/n02109961_1017
# Annotation/n02109961-Eskimo_dog/n02109961_1032
# Annotation/n02109961-Eskimo_dog/n02109961_10660
# Annotation/n02109961-Eskimo_dog/n02109961_10699
# Annotation/n02109961-Eskimo_dog/n02109961_1076
# Annotation/n02109961-Eskimo_dog/n02109961_10774
# Annotation/n02109961-Eskimo_dog/n02109961_11224
# Annotation/n02109961-Eskimo_dog/n02109961_11511
# Annotation/n02109961-Eskimo_dog/n02109961_11634
# Annotation/n02109961-Eskimo_dog/n02109961_12107
# Annotation/n02109961-Eskimo_dog/n02109961_12118
# Annotation/n02109961-Eskimo_dog/n02109961_12338
# Annotation/n02109961-Eskimo_dog/n02109961_1235
# Annotation/n02109961-Eskimo_dog/n02109961_1251
# Annotation/n02109961-Eskimo_dog/n02109961_1253
# Annotation/n02109961-Eskimo_dog/n02109961_12719
# Annotation/n02109961-Eskimo_dog/n02109961_1276
# Annotation/n02109961-Eskimo_dog/n02109961_12993
# Annotation/n02109961-Eskimo_dog/n02109961_13077
# Annotation/n02109961-Eskimo_dog/n02109961_131
# Annotation/n02109961-Eskimo_dog/n02109961_1328
# Annotation/n02109961-Eskimo_dog/n02109961_135
# Annotation/n02109961-Eskimo_dog/n02109961_1351
# Annotation/n02109961-Eskimo_dog/n02109961_1413
# Annotation/n02109961-Eskimo_dog/n02109961_15257
# Annotation/n02109961-Eskimo_dog/n02109961_15315
# Annotation/n02109961-Eskimo_dog/n02109961_16095
# Annotation/n02109961-Eskimo_dog/n02109961_1613
# Annotation/n02109961-Eskimo_dog/n02109961_16311
# Annotation/n02109961-Eskimo_dog/n02109961_1633
# Annotation/n02109961-Eskimo_dog/n02109961_16491
# Annotation/n02109961-Eskimo_dog/n02109961_16718
# Annotation/n02109961-Eskimo_dog/n02109961_1678
# Annotation/n02109961-Eskimo_dog/n02109961_16865
# Annotation/n02109961-Eskimo_dog/n02109961_16953
# Annotation/n02109961-Eskimo_dog/n02109961_16961
# Annotation/n02109961-Eskimo_dog/n02109961_17006
# Annotation/n02109961-Eskimo_dog/n02109961_17033
# Annotation/n02109961-Eskimo_dog/n02109961_17082
# Annotation/n02109961-Eskimo_dog/n02109961_17141
# Annotation/n02109961-Eskimo_dog/n02109961_1767
# Annotation/n02109961-Eskimo_dog/n02109961_18009
# Annotation/n02109961-Eskimo_dog/n02109961_18163
# Annotation/n02109961-Eskimo_dog/n02109961_18381
# Annotation/n02109961-Eskimo_dog/n02109961_18454
# Annotation/n02109961-Eskimo_dog/n02109961_18527
# Annotation/n02109961-Eskimo_dog/n02109961_18552
# Annotation/n02109961-Eskimo_dog/n02109961_19261
# Annotation/n02109961-Eskimo_dog/n02109961_19358
# Annotation/n02109961-Eskimo_dog/n02109961_1948
# Annotation/n02109961-Eskimo_dog/n02109961_1949
# Annotation/n02109961-Eskimo_dog/n02109961_1971
# Annotation/n02109961-Eskimo_dog/n02109961_20002
# Annotation/n02109961-Eskimo_dog/n02109961_20013
# Annotation/n02109961-Eskimo_dog/n02109961_20429
# Annotation/n02109961-Eskimo_dog/n02109961_21073
# Annotation/n02109961-Eskimo_dog/n02109961_21096
# Annotation/n02109961-Eskimo_dog/n02109961_2188
# Annotation/n02109961-Eskimo_dog/n02109961_2272
# Annotation/n02109961-Eskimo_dog/n02109961_2317
# Annotation/n02109961-Eskimo_dog/n02109961_2369
# Annotation/n02109961-Eskimo_dog/n02109961_2388
# Annotation/n02109961-Eskimo_dog/n02109961_2406
# Annotation/n02109961-Eskimo_dog/n02109961_2492
# Annotation/n02109961-Eskimo_dog/n02109961_2522
# Annotation/n02109961-Eskimo_dog/n02109961_2532
# Annotation/n02109961-Eskimo_dog/n02109961_2555
# Annotation/n02109961-Eskimo_dog/n02109961_2584
# Annotation/n02109961-Eskimo_dog/n02109961_2599
# Annotation/n02109961-Eskimo_dog/n02109961_2608
# Annotation/n02109961-Eskimo_dog/n02109961_2609
# Annotation/n02109961-Eskimo_dog/n02109961_2675
# Annotation/n02109961-Eskimo_dog/n02109961_2706
# Annotation/n02109961-Eskimo_dog/n02109961_2727
# Annotation/n02109961-Eskimo_dog/n02109961_2832
# Annotation/n02109961-Eskimo_dog/n02109961_2932
# Annotation/n02109961-Eskimo_dog/n02109961_2964
# ...
# Annotation/n02115641-dingo/n02115641_9686
# Annotation/n02115641-dingo/n02115641_970
# Annotation/n02115641-dingo/n02115641_9763
# Annotation/n02115641-dingo/n02115641_9977
# Annotation/n02115913-dhole/
# Annotation/n02115913-dhole/n02115913_1010
# Annotation/n02115913-dhole/n02115913_1047
# Annotation/n02115913-dhole/n02115913_1060
# Annotation/n02115913-dhole/n02115913_1066
# Annotation/n02115913-dhole/n02115913_1067
# Annotation/n02115913-dhole/n02115913_1142
# Annotation/n02115913-dhole/n02115913_1188
# Annotation/n02115913-dhole/n02115913_1213
# Annotation/n02115913-dhole/n02115913_1224
# Annotation/n02115913-dhole/n02115913_1233
# Annotation/n02115913-dhole/n02115913_1244
# Annotation/n02115913-dhole/n02115913_1273
# Annotation/n02115913-dhole/n02115913_1288
# Annotation/n02115913-dhole/n02115913_1323
# Annotation/n02115913-dhole/n02115913_1332
# Annotation/n02115913-dhole/n02115913_1334
# Annotation/n02115913-dhole/n02115913_1352
# Annotation/n02115913-dhole/n02115913_139
# Annotation/n02115913-dhole/n02115913_1449
# Annotation/n02115913-dhole/n02115913_1493
# Annotation/n02115913-dhole/n02115913_1522
# Annotation/n02115913-dhole/n02115913_1552
# Annotation/n02115913-dhole/n02115913_1578
# Annotation/n02115913-dhole/n02115913_1622
# Annotation/n02115913-dhole/n02115913_1631
# Annotation/n02115913-dhole/n02115913_1637
# Annotation/n02115913-dhole/n02115913_1663
# Annotation/n02115913-dhole/n02115913_1677
# Annotation/n02115913-dhole/n02115913_1682
# Annotation/n02115913-dhole/n02115913_1688
# Annotation/n02115913-dhole/n02115913_1742
# Annotation/n02115913-dhole/n02115913_1744
# Annotation/n02115913-dhole/n02115913_1772
# Annotation/n02115913-dhole/n02115913_1796
# Annotation/n02115913-dhole/n02115913_1830
# Annotation/n02115913-dhole/n02115913_1897
# Annotation/n02115913-dhole/n02115913_1963
# Annotation/n02115913-dhole/n02115913_1979
# Annotation/n02115913-dhole/n02115913_2005
# Annotation/n02115913-dhole/n02115913_2014
# Annotation/n02115913-dhole/n02115913_2029
# Annotation/n02115913-dhole/n02115913_2044
# Annotation/n02115913-dhole/n02115913_2138
# Annotation/n02115913-dhole/n02115913_219
# Annotation/n02115913-dhole/n02115913_2253
# Annotation/n02115913-dhole/n02115913_2259
# Annotation/n02115913-dhole/n02115913_2264
# Annotation/n02115913-dhole/n02115913_2300
# Annotation/n02115913-dhole/n02115913_2320
# Annotation/n02115913-dhole/n02115913_2325
# Annotation/n02115913-dhole/n02115913_2338
# Annotation/n02115913-dhole/n02115913_2365
# Annotation/n02115913-dhole/n02115913_2412
# Annotation/n02115913-dhole/n02115913_2414
# Annotation/n02115913-dhole/n02115913_2480
# Annotation/n02115913-dhole/n02115913_25
# Annotation/n02115913-dhole/n02115913_250
# Annotation/n02115913-dhole/n02115913_2520
# Annotation/n02115913-dhole/n02115913_2524
# Annotation/n02115913-dhole/n02115913_253
# Annotation/n02115913-dhole/n02115913_2542
# Annotation/n02115913-dhole/n02115913_257
# Annotation/n02115913-dhole/n02115913_2579
# Annotation/n02115913-dhole/n02115913_262
# Annotation/n02115913-dhole/n02115913_2657
# Annotation/n02115913-dhole/n02115913_2841
# Annotation/n02115913-dhole/n02115913_2895
# Annotation/n02115913-dhole/n02115913_3010
# Annotation/n02115913-dhole/n02115913_3052
# Annotation/n02115913-dhole/n02115913_3107
# Annotation/n02115913-dhole/n02115913_311
# Annotation/n02115913-dhole/n02115913_3115
# Annotation/n02115913-dhole/n02115913_312
# Annotation/n02115913-dhole/n02115913_3178
# Annotation/n02115913-dhole/n02115913_3196
# Annotation/n02115913-dhole/n02115913_3229
# Annotation/n02115913-dhole/n02115913_3270
# Annotation/n02115913-dhole/n02115913_3278
# Annotation/n02115913-dhole/n02115913_3313
# Annotation/n02115913-dhole/n02115913_3465
# Annotation/n02115913-dhole/n02115913_3473
# Annotation/n02115913-dhole/n02115913_3480
# Annotation/n02115913-dhole/n02115913_3527
# Annotation/n02115913-dhole/n02115913_3529
# Annotation/n02115913-dhole/n02115913_359
# Annotation/n02115913-dhole/n02115913_3601
# Annotation/n02115913-dhole/n02115913_3647
# Annotation/n02115913-dhole/n02115913_368
# Annotation/n02115913-dhole/n02115913_3740
# Annotation/n02115913-dhole/n02115913_3743
# Annotation/n02115913-dhole/n02115913_3753
# Annotation/n02115913-dhole/n02115913_38
# Annotation/n02115913-dhole/n02115913_3800
# Annotation/n02115913-dhole/n02115913_3842
# Annotation/n02115913-dhole/n02115913_3850
# Annotation/n02115913-dhole/n02115913_3854
# Annotation/n02115913-dhole/n02115913_3863
# Annotation/n02115913-dhole/n02115913_3875
# Annotation/n02115913-dhole/n02115913_3878
# Annotation/n02115913-dhole/n02115913_3902
# Annotation/n02115913-dhole/n02115913_3918
# Annotation/n02115913-dhole/n02115913_3991
# Annotation/n02115913-dhole/n02115913_3994
# Annotation/n02115913-dhole/n02115913_3998
# Annotation/n02115913-dhole/n02115913_4025
# Annotation/n02115913-dhole/n02115913_4031
# Annotation/n02115913-dhole/n02115913_4032
# Annotation/n02115913-dhole/n02115913_4047
# Annotation/n02115913-dhole/n02115913_4055
# Annotation/n02115913-dhole/n02115913_4059
# Annotation/n02115913-dhole/n02115913_4082
# Annotation/n02115913-dhole/n02115913_4110
# Annotation/n02115913-dhole/n02115913_4117
# Annotation/n02115913-dhole/n02115913_4119
# Annotation/n02115913-dhole/n02115913_4128
# Annotation/n02115913-dhole/n02115913_4129
# Annotation/n02115913-dhole/n02115913_4144
# Annotation/n02115913-dhole/n02115913_4163
# Annotation/n02115913-dhole/n02115913_4179
# Annotation/n02115913-dhole/n02115913_4188
# Annotation/n02115913-dhole/n02115913_423
# Annotation/n02115913-dhole/n02115913_4266
# Annotation/n02115913-dhole/n02115913_4273
# Annotation/n02115913-dhole/n02115913_4275
# Annotation/n02115913-dhole/n02115913_4308
# Annotation/n02115913-dhole/n02115913_4313
# Annotation/n02115913-dhole/n02115913_4320
# Annotation/n02115913-dhole/n02115913_4336
# Annotation/n02115913-dhole/n02115913_44
# Annotation/n02115913-dhole/n02115913_4429
# Annotation/n02115913-dhole/n02115913_4542
# Annotation/n02115913-dhole/n02115913_520
# Annotation/n02115913-dhole/n02115913_539
# Annotation/n02115913-dhole/n02115913_5392
# Annotation/n02115913-dhole/n02115913_5418
# Annotation/n02115913-dhole/n02115913_5469
# Annotation/n02115913-dhole/n02115913_5507
# Annotation/n02115913-dhole/n02115913_5593
# Annotation/n02115913-dhole/n02115913_564
# Annotation/n02115913-dhole/n02115913_593
# Annotation/n02115913-dhole/n02115913_612
# Annotation/n02115913-dhole/n02115913_614
# Annotation/n02115913-dhole/n02115913_676
# Annotation/n02115913-dhole/n02115913_678
# Annotation/n02115913-dhole/n02115913_739
# Annotation/n02115913-dhole/n02115913_750
# Annotation/n02115913-dhole/n02115913_90
# Annotation/n02115913-dhole/n02115913_907
# Annotation/n02115913-dhole/n02115913_915
# Annotation/n02115913-dhole/n02115913_92
# Annotation/n02116738-African_hunting_dog/
# Annotation/n02116738-African_hunting_dog/n02116738_10024
# Annotation/n02116738-African_hunting_dog/n02116738_10038
# Annotation/n02116738-African_hunting_dog/n02116738_10081
# Annotation/n02116738-African_hunting_dog/n02116738_10169
# Annotation/n02116738-African_hunting_dog/n02116738_10215
# Annotation/n02116738-African_hunting_dog/n02116738_10469
# Annotation/n02116738-African_hunting_dog/n02116738_10476
# Annotation/n02116738-African_hunting_dog/n02116738_10493
# Annotation/n02116738-African_hunting_dog/n02116738_10575
# Annotation/n02116738-African_hunting_dog/n02116738_10614
# Annotation/n02116738-African_hunting_dog/n02116738_10640
# Annotation/n02116738-African_hunting_dog/n02116738_10872
# Annotation/n02116738-African_hunting_dog/n02116738_10895
# Annotation/n02116738-African_hunting_dog/n02116738_1097
# Annotation/n02116738-African_hunting_dog/n02116738_1105
# Annotation/n02116738-African_hunting_dog/n02116738_1180
# Annotation/n02116738-African_hunting_dog/n02116738_124
# Annotation/n02116738-African_hunting_dog/n02116738_1398
# Annotation/n02116738-African_hunting_dog/n02116738_1591
# Annotation/n02116738-African_hunting_dog/n02116738_1627
# Annotation/n02116738-African_hunting_dog/n02116738_1739
# Annotation/n02116738-African_hunting_dog/n02116738_1815
# Annotation/n02116738-African_hunting_dog/n02116738_1849
# Annotation/n02116738-African_hunting_dog/n02116738_1927
# Annotation/n02116738-African_hunting_dog/n02116738_1948
# Annotation/n02116738-African_hunting_dog/n02116738_2005
# Annotation/n02116738-African_hunting_dog/n02116738_2020
# Annotation/n02116738-African_hunting_dog/n02116738_204
# Annotation/n02116738-African_hunting_dog/n02116738_2083
# Annotation/n02116738-African_hunting_dog/n02116738_2139
# Annotation/n02116738-African_hunting_dog/n02116738_219
# Annotation/n02116738-African_hunting_dog/n02116738_2192
# Annotation/n02116738-African_hunting_dog/n02116738_2327
# Annotation/n02116738-African_hunting_dog/n02116738_2329
# Annotation/n02116738-African_hunting_dog/n02116738_233
# Annotation/n02116738-African_hunting_dog/n02116738_2344
# Annotation/n02116738-African_hunting_dog/n02116738_2435
# Annotation/n02116738-African_hunting_dog/n02116738_246
# Annotation/n02116738-African_hunting_dog/n02116738_2482
# Annotation/n02116738-African_hunting_dog/n02116738_2503
# Annotation/n02116738-African_hunting_dog/n02116738_2514
# Annotation/n02116738-African_hunting_dog/n02116738_2515
# Annotation/n02116738-African_hunting_dog/n02116738_2557
# Annotation/n02116738-African_hunting_dog/n02116738_2599
# Annotation/n02116738-African_hunting_dog/n02116738_2600
# Annotation/n02116738-African_hunting_dog/n02116738_2614
# Annotation/n02116738-African_hunting_dog/n02116738_2675
# Annotation/n02116738-African_hunting_dog/n02116738_2757
# Annotation/n02116738-African_hunting_dog/n02116738_2770
# Annotation/n02116738-African_hunting_dog/n02116738_2802
# Annotation/n02116738-African_hunting_dog/n02116738_288
# Annotation/n02116738-African_hunting_dog/n02116738_291
# Annotation/n02116738-African_hunting_dog/n02116738_2942
# Annotation/n02116738-African_hunting_dog/n02116738_2988
# Annotation/n02116738-African_hunting_dog/n02116738_3024
# Annotation/n02116738-African_hunting_dog/n02116738_308
# Annotation/n02116738-African_hunting_dog/n02116738_3160
# Annotation/n02116738-African_hunting_dog/n02116738_328
# Annotation/n02116738-African_hunting_dog/n02116738_3365
# Annotation/n02116738-African_hunting_dog/n02116738_3422
# Annotation/n02116738-African_hunting_dog/n02116738_3589
# Annotation/n02116738-African_hunting_dog/n02116738_3635
# Annotation/n02116738-African_hunting_dog/n02116738_3692
# Annotation/n02116738-African_hunting_dog/n02116738_3720
# Annotation/n02116738-African_hunting_dog/n02116738_3819
# Annotation/n02116738-African_hunting_dog/n02116738_385
# Annotation/n02116738-African_hunting_dog/n02116738_4019
# Annotation/n02116738-African_hunting_dog/n02116738_4098
# Annotation/n02116738-African_hunting_dog/n02116738_4102
# Annotation/n02116738-African_hunting_dog/n02116738_4115
# Annotation/n02116738-African_hunting_dog/n02116738_4138
# Annotation/n02116738-African_hunting_dog/n02116738_431
# Annotation/n02116738-African_hunting_dog/n02116738_4323
# Annotation/n02116738-African_hunting_dog/n02116738_4335
# Annotation/n02116738-African_hunting_dog/n02116738_4367
# Annotation/n02116738-African_hunting_dog/n02116738_4382
# Annotation/n02116738-African_hunting_dog/n02116738_4461
# Annotation/n02116738-African_hunting_dog/n02116738_4508
# Annotation/n02116738-African_hunting_dog/n02116738_4641
# Annotation/n02116738-African_hunting_dog/n02116738_4720
# Annotation/n02116738-African_hunting_dog/n02116738_4732
# Annotation/n02116738-African_hunting_dog/n02116738_4734
# Annotation/n02116738-African_hunting_dog/n02116738_4742
# Annotation/n02116738-African_hunting_dog/n02116738_4758
# Annotation/n02116738-African_hunting_dog/n02116738_4796
# Annotation/n02116738-African_hunting_dog/n02116738_4834
# Annotation/n02116738-African_hunting_dog/n02116738_4991
# Annotation/n02116738-African_hunting_dog/n02116738_500
# Annotation/n02116738-African_hunting_dog/n02116738_5068
# Annotation/n02116738-African_hunting_dog/n02116738_5241
# Annotation/n02116738-African_hunting_dog/n02116738_5312
# Annotation/n02116738-African_hunting_dog/n02116738_5338
# Annotation/n02116738-African_hunting_dog/n02116738_5519
# Annotation/n02116738-African_hunting_dog/n02116738_5635
# Annotation/n02116738-African_hunting_dog/n02116738_5661
# Annotation/n02116738-African_hunting_dog/n02116738_5683
# Annotation/n02116738-African_hunting_dog/n02116738_5697
# Annotation/n02116738-African_hunting_dog/n02116738_5932
# Annotation/n02116738-African_hunting_dog/n02116738_5936
# Annotation/n02116738-African_hunting_dog/n02116738_5953
# Annotation/n02116738-African_hunting_dog/n02116738_5956
# Annotation/n02116738-African_hunting_dog/n02116738_5993
# Annotation/n02116738-African_hunting_dog/n02116738_6038
# Annotation/n02116738-African_hunting_dog/n02116738_6044
# Annotation/n02116738-African_hunting_dog/n02116738_607
# Annotation/n02116738-African_hunting_dog/n02116738_6076
# Annotation/n02116738-African_hunting_dog/n02116738_6092
# Annotation/n02116738-African_hunting_dog/n02116738_6117
# Annotation/n02116738-African_hunting_dog/n02116738_6283
# Annotation/n02116738-African_hunting_dog/n02116738_6297
# Annotation/n02116738-African_hunting_dog/n02116738_6330
# Annotation/n02116738-African_hunting_dog/n02116738_634
# Annotation/n02116738-African_hunting_dog/n02116738_6563
# Annotation/n02116738-African_hunting_dog/n02116738_662
# Annotation/n02116738-African_hunting_dog/n02116738_6746
# Annotation/n02116738-African_hunting_dog/n02116738_6748
# Annotation/n02116738-African_hunting_dog/n02116738_6754
# Annotation/n02116738-African_hunting_dog/n02116738_678
# Annotation/n02116738-African_hunting_dog/n02116738_6790
# Annotation/n02116738-African_hunting_dog/n02116738_6813
# Annotation/n02116738-African_hunting_dog/n02116738_684
# Annotation/n02116738-African_hunting_dog/n02116738_7008
# Annotation/n02116738-African_hunting_dog/n02116738_7026
# Annotation/n02116738-African_hunting_dog/n02116738_7060
# Annotation/n02116738-African_hunting_dog/n02116738_7105
# Annotation/n02116738-African_hunting_dog/n02116738_7122
# Annotation/n02116738-African_hunting_dog/n02116738_7170
# Annotation/n02116738-African_hunting_dog/n02116738_7340
# Annotation/n02116738-African_hunting_dog/n02116738_7506
# Annotation/n02116738-African_hunting_dog/n02116738_7537
# Annotation/n02116738-African_hunting_dog/n02116738_7578
# Annotation/n02116738-African_hunting_dog/n02116738_7580
# Annotation/n02116738-African_hunting_dog/n02116738_7590
# Annotation/n02116738-African_hunting_dog/n02116738_7601
# Annotation/n02116738-African_hunting_dog/n02116738_7657
# Annotation/n02116738-African_hunting_dog/n02116738_7753
# Annotation/n02116738-African_hunting_dog/n02116738_7988
# Annotation/n02116738-African_hunting_dog/n02116738_8037
# Annotation/n02116738-African_hunting_dog/n02116738_806
# Annotation/n02116738-African_hunting_dog/n02116738_8095
# Annotation/n02116738-African_hunting_dog/n02116738_8226
# Annotation/n02116738-African_hunting_dog/n02116738_8341
# Annotation/n02116738-African_hunting_dog/n02116738_8403
# Annotation/n02116738-African_hunting_dog/n02116738_8489
# Annotation/n02116738-African_hunting_dog/n02116738_849
# Annotation/n02116738-African_hunting_dog/n02116738_8512
# Annotation/n02116738-African_hunting_dog/n02116738_8579
# Annotation/n02116738-African_hunting_dog/n02116738_8653
# Annotation/n02116738-African_hunting_dog/n02116738_8662
# Annotation/n02116738-African_hunting_dog/n02116738_8669
# Annotation/n02116738-African_hunting_dog/n02116738_8696
# Annotation/n02116738-African_hunting_dog/n02116738_8719
# Annotation/n02116738-African_hunting_dog/n02116738_8734
# Annotation/n02116738-African_hunting_dog/n02116738_8738
# Annotation/n02116738-African_hunting_dog/n02116738_8749
# Annotation/n02116738-African_hunting_dog/n02116738_8945
# Annotation/n02116738-African_hunting_dog/n02116738_9164
# Annotation/n02116738-African_hunting_dog/n02116738_9232
# Annotation/n02116738-African_hunting_dog/n02116738_9282
# Annotation/n02116738-African_hunting_dog/n02116738_9333
# Annotation/n02116738-African_hunting_dog/n02116738_9603
# Annotation/n02116738-African_hunting_dog/n02116738_9748
# Annotation/n02116738-African_hunting_dog/n02116738_9762
# Annotation/n02116738-African_hunting_dog/n02116738_9769
# Annotation/n02116738-African_hunting_dog/n02116738_9798
# Annotation/n02116738-African_hunting_dog/n02116738_9818
# Annotation/n02116738-African_hunting_dog/n02116738_9829
# Annotation/n02116738-African_hunting_dog/n02116738_9844
# Annotation/n02116738-African_hunting_dog/n02116738_9924

# %%
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import torch
from torchvision import models
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn.functional as F
import torchvision

from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import utils
import os
import json
import re
import random
from math import sqrt

# %%
print(os.listdir("../content"))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# ['.config', 'Images', 'coco_eval.py', 'gdrive', 'Annotation', 'utils.py', 'engine.py', 'transforms.py', 'vision', 'coco_utils.py', '__pycache__', 'sample_data']

# %%
with open('../content/Annotation/n02113799-standard_poodle/n02113799_489') as f:
    reader = f.read()

img = Image.open('../content/Images/n02113799-standard_poodle/n02113799_489.jpg')

xmin = int(re.findall('(?<=<xmin>)[0-9]+?(?=</xmin>)', reader)[0])
xmax = int(re.findall('(?<=<xmax>)[0-9]+?(?=</xmax>)', reader)[0])
ymin = int(re.findall('(?<=<ymin>)[0-9]+?(?=</ymin>)', reader)[0])
ymax = int(re.findall('(?<=<ymax>)[0-9]+?(?=</ymax>)', reader)[0])

origin_img = img.copy()
draw = ImageDraw.Draw(origin_img)
draw.rectangle(xy=[(xmin,ymin), (xmax,ymax)])
origin_img
# Out:
# <PIL.Image.Image image mode=RGB size=375x500 at 0x7FBB58A23700>

# %%
dims=(224, 224)
old_dims = torch.FloatTensor([img.width, img.height, img.width, img.height]).unsqueeze(0)
box = torch.FloatTensor([xmin, ymin, xmax, ymax])
new_box = box / old_dims
new_dims = torch.FloatTensor([dims[1], dims[0], dims[1], dims[0]]).unsqueeze(0)
# print(new_dims)
new_box = new_box * new_dims
new_box
# Out:
# tensor([[ 31.6587,  52.8640, 197.1200, 216.3840]])

# %%
old_dims
new_box.tolist()
# Out:
# [[31.65866470336914, 52.86399841308594, 197.1199951171875, 216.38400268554688]]

# %%
img = transforms.Resize(dims)(img)
draw = ImageDraw.Draw(img)
draw.rectangle(xy=[tuple(new_box.tolist()[0])[:2], tuple(new_box.tolist()[0])[2:]])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FBA87985E10>

# %%
label_map = {'dog': 1}

rev_label_map = {
    1: 'dog',
    0: 'background'
}

# %%
all_img_folder = os.listdir('../content/Images')
# all_annotation_folder = os.listdir('../input/annotations/Annotation')

all_img_name = []
for img_folder in all_img_folder:
    img_folder_path = '../content/Images/' + img_folder
    all_img_name += list(map(lambda x: img_folder + '/'+ x, os.listdir(img_folder_path)))

# all_annotation_name = []
# for annotation_folder in all_annotation_folder:
#     annotation_folder_path = '../input/annotations/Annotation/' + annotation_folder
#     all_annotation_name += list(map(lambda x: annotation_folder + '/'+ x, os.listdir(annotation_folder_path)))

len(all_img_name), all_img_name[0]
# Out:
# (20580, 'n02110806-basenji/n02110806_4280.jpg')

# %%
class DogDataSet(Dataset):
    def __init__(self, file_folder, is_test=False, transform=None):
        self.img_folder_path = '../content/Images/'
        self.annotation_folder_path = '../content/Annotation/'
        self.file_folder = file_folder
        self.transform = transform
        self.is_test = is_test
        
    def __getitem__(self, idx):
        file = self.file_folder[idx]
        img_path = self.img_folder_path + file
        img = Image.open(img_path)
        img = img.convert('RGB')
        
        if not self.is_test:
            annotation_path = self.annotation_folder_path + file.split('.')[0]
            with open(annotation_path) as f:
                annotation = f.read()

            xy = self.get_xy(annotation)
            box = torch.LongTensor(list(xy))

            new_box = self.box_resize(box, img)
            if(all(isinstance(i, list) for i in box.tolist())==True):
                area = (box[:,2] - box[:,0])*(box[:,3] - box[:,1])
            else:
                area = (box[2] - box[0])*(box[3] - box[1])

            area = torch.tensor([area])

            if self.transform is not None:
                img = self.transform(img)
            target = {}
            target["boxes"] = new_box
            target["labels"] = torch.LongTensor([1])
            target["image_id"] = torch.LongTensor([idx])
            target["area"] = area
            target["iscrowd"] = torch.LongTensor([0])
            return img,target
        else:
            return img
    
    def __len__(self):
        return len(self.file_folder)
        
    def get_xy(self, annotation):
        xmin = int(re.findall('(?<=<xmin>)[0-9]+?(?=</xmin>)', annotation)[0])
        xmax = int(re.findall('(?<=<xmax>)[0-9]+?(?=</xmax>)', annotation)[0])
        ymin = int(re.findall('(?<=<ymin>)[0-9]+?(?=</ymin>)', annotation)[0])
        ymax = int(re.findall('(?<=<ymax>)[0-9]+?(?=</ymax>)', annotation)[0])
        
        return xmin, ymin, xmax, ymax
    
    def show_box(self):
        file = random.choice(self.file_folder)
        annotation_path = self.annotation_folder_path + file.split('.')[0]
        
        img_box = Image.open(self.img_folder_path + file)
        with open(annotation_path) as f:
            annotation = f.read()
            
        draw = ImageDraw.Draw(img_box)
        xy = self.get_xy(annotation)
        draw.rectangle(xy=[xy[:2], xy[2:]])
        
        return img_box
        
    def box_resize(self, box, img, dims=(300, 300)):
        old_dims = torch.FloatTensor([img.width, img.height, img.width, img.height]).unsqueeze(0)
        new_box = box / old_dims
        new_dims = torch.FloatTensor([dims[1], dims[0], dims[1], dims[0]]).unsqueeze(0)
#         new_box = new_box * new_dims
        
        return new_box
    
    def collate_fn(self, batch):
        """
        Since each image may have a different number of objects, we need a collate function (to be passed to the DataLoader).
        This describes how to combine these tensors of different sizes. We use lists.
         bounding boxes, labels, and difficulties
        """
        return torch.utils.collate_fn

# %%
tsfm = transforms.Compose([
    transforms.Resize([300, 300]),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
])

# %%
def xy_to_cxcy(xy):
    """
    Convert bounding boxes from boundary coordinates (x_min, y_min, x_max, y_max) to center-size coordinates (c_x, c_y, w, h)
    """
    return torch.cat([(xy[:, 2:] + xy[:, :2]) / 2,  # c_x, c_y
                      xy[:, 2:] - xy[:, :2]], 1)  # w, h


def cxcy_to_xy(cxcy):
    """
    Convert bounding boxes from center-size coordinates (c_x, c_y, w, h) to boundary coordinates (x_min, y_min, x_max, y_max).
    """
    return torch.cat([cxcy[:, :2] - (cxcy[:, 2:] / 2),  # x_min, y_min
                      cxcy[:, :2] + (cxcy[:, 2:] / 2)], 1)  # x_max, y_max


def cxcy_to_gcxgcy(cxcy, priors_cxcy):
    """
    Encode bounding boxes (that are in center-size form) w.r.t. the corresponding prior boxes (that are in center-size form).
    For the center coordinates, find the offset with respect to the prior box, and scale by the size of the prior box.
    """

    # The 10 and 5 below are referred to as 'variances' in the original Caffe repo, completely empirical
    # They are for some sort of numerical conditioning, for 'scaling the localization gradient'
    # See https://github.com/weiliu89/caffe/issues/155
    return torch.cat([(cxcy[:, :2] - priors_cxcy[:, :2]) / (priors_cxcy[:, 2:] / 10),  # g_c_x, g_c_y
                      torch.log(cxcy[:, 2:] / priors_cxcy[:, 2:]) * 5], 1)  # g_w, g_h


def gcxgcy_to_cxcy(gcxgcy, priors_cxcy):
    """
    Decode bounding box coordinates predicted by the model, since they are encoded in the form mentioned above.
    They are decoded into center-size coordinates.
    This is the inverse of the function above.
    """

    return torch.cat([gcxgcy[:, :2] * priors_cxcy[:, 2:] / 10 + priors_cxcy[:, :2],  # c_x, c_y
                      torch.exp(gcxgcy[:, 2:] / 5) * priors_cxcy[:, 2:]], 1)  # w, h

def find_jaccard_overlap(set_1, set_2):
    """
    Find the Jaccard Overlap (IoU) of every box combination between two sets of boxes that are in boundary coordinates.
    """

    # Find intersections
    intersection = find_intersection(set_1, set_2)  # (n1, n2)

    # Find areas of each box in both sets
    areas_set_1 = (set_1[:, 2] - set_1[:, 0]) * (set_1[:, 3] - set_1[:, 1])  # (n1)
    areas_set_2 = (set_2[:, 2] - set_2[:, 0]) * (set_2[:, 3] - set_2[:, 1])  # (n2)

    # Find the union
    # PyTorch auto-broadcasts singleton dimensions
    union = areas_set_1.unsqueeze(1) + areas_set_2.unsqueeze(0) - intersection  # (n1, n2)

    return intersection / union  # (n1, n2)

def find_intersection(set_1, set_2):
    """
    Find the intersection of every box combination between two sets of boxes that are in boundary coordinates.
    of the boxes in set 1 with respect to each of the boxes in set 2, a tensor of dimensions (n1, n2)
    """

    # PyTorch auto-broadcasts singleton dimensions
    lower_bounds = torch.max(set_1[:, :2].unsqueeze(1), set_2[:, :2].unsqueeze(0))  # (n1, n2, 2)
    upper_bounds = torch.min(set_1[:, 2:].unsqueeze(1), set_2[:, 2:].unsqueeze(0))  # (n1, n2, 2)
    intersection_dims = torch.clamp(upper_bounds - lower_bounds, min=0)  # (n1, n2, 2)
    return intersection_dims[:, :, 0] * intersection_dims[:, :, 1]  # (n1, n2)

def decimate(tensor, m):
    """
    Decimate a tensor by a factor 'm', i.e. downsample by keeping every 'm'th value.
    This is used when we convert FC layers to equivalent Convolutional layers, BUT of a smaller size.
    """
    assert tensor.dim() == len(m)
    for d in range(tensor.dim()):
        if m[d] is not None:
            tensor = tensor.index_select(dim=d,
                                         index=torch.arange(start=0, end=tensor.size(d), step=m[d]).long())

    return tensor

def calculate_mAP(det_boxes, det_labels, det_scores, true_boxes, true_labels, true_difficulties):
    """
    Calculate the Mean Average Precision (mAP) of detected objects.
    See https://medium.com/@jonathan_hui/map-mean-average-precision-for-object-detection-45c121a31173 for an explanation
    :param det_boxes: list of tensors, one tensor for each image containing detected objects' bounding boxes
    :param det_labels: list of tensors, one tensor for each image containing detected objects' labels
    :param det_scores: list of tensors, one tensor for each image containing detected objects' labels' scores
    :param true_boxes: list of tensors, one tensor for each image containing actual objects' bounding boxes
    :param true_labels: list of tensors, one tensor for each image containing actual objects' labels
    :param true_difficulties: list of tensors, one tensor for each image containing actual objects' difficulty (0 or 1)
    :return: list of average precisions for all classes, mean average precision (mAP)
    """
    assert len(det_boxes) == len(det_labels) == len(det_scores) == len(true_boxes) == len(
        true_labels) == len(
        true_difficulties)  # these are all lists of tensors of the same length, i.e. number of images
    n_classes = len(label_map)

    # Store all (true) objects in a single continuous tensor while keeping track of the image it is from
    true_images = list()
    for i in range(len(true_labels)):
        true_images.extend([i] * true_labels[i].size(0))
    true_images = torch.LongTensor(true_images).to(
        device)  # (n_objects), n_objects is the total no. of objects across all images
    true_boxes = torch.cat(true_boxes, dim=0)  # (n_objects, 4)
    true_labels = torch.cat(true_labels, dim=0)  # (n_objects)
    true_difficulties = torch.cat(true_difficulties, dim=0)  # (n_objects)

    assert true_images.size(0) == true_boxes.size(0) == true_labels.size(0)

    # Store all detections in a single continuous tensor while keeping track of the image it is from
    det_images = list()
    for i in range(len(det_labels)):
        det_images.extend([i] * det_labels[i].size(0))
    det_images = torch.LongTensor(det_images).to(device)  # (n_detections)
    det_boxes = torch.cat(det_boxes, dim=0)  # (n_detections, 4)
    det_labels = torch.cat(det_labels, dim=0)  # (n_detections)
    det_scores = torch.cat(det_scores, dim=0)  # (n_detections)

    assert det_images.size(0) == det_boxes.size(0) == det_labels.size(0) == det_scores.size(0)

    # Calculate APs for each class (except background)
    average_precisions = torch.zeros((n_classes - 1), dtype=torch.float)  # (n_classes - 1)
    for c in range(1, n_classes):
        # Extract only objects with this class
        true_class_images = true_images[true_labels == c]  # (n_class_objects)
        true_class_boxes = true_boxes[true_labels == c]  # (n_class_objects, 4)
        true_class_difficulties = true_difficulties[true_labels == c]  # (n_class_objects)
        n_easy_class_objects = (1 - true_class_difficulties).sum().item()  # ignore difficult objects

        # Keep track of which true objects with this class have already been 'detected'
        # So far, none
        true_class_boxes_detected = torch.zeros((true_class_difficulties.size(0)), dtype=torch.uint8).to(
            device)  # (n_class_objects)

        # Extract only detections with this class
        det_class_images = det_images[det_labels == c]  # (n_class_detections)
        det_class_boxes = det_boxes[det_labels == c]  # (n_class_detections, 4)
        det_class_scores = det_scores[det_labels == c]  # (n_class_detections)
        n_class_detections = det_class_boxes.size(0)
        if n_class_detections == 0:
            continue

        # Sort detections in decreasing order of confidence/scores
        det_class_scores, sort_ind = torch.sort(det_class_scores, dim=0, descending=True)  # (n_class_detections)
        det_class_images = det_class_images[sort_ind]  # (n_class_detections)
        det_class_boxes = det_class_boxes[sort_ind]  # (n_class_detections, 4)

        # In the order of decreasing scores, check if true or false positive
        true_positives = torch.zeros((n_class_detections), dtype=torch.float).to(device)  # (n_class_detections)
        false_positives = torch.zeros((n_class_detections), dtype=torch.float).to(device)  # (n_class_detections)
        for d in range(n_class_detections):
            this_detection_box = det_class_boxes[d].unsqueeze(0)  # (1, 4)
            this_image = det_class_images[d]  # (), scalar

            # Find objects in the same image with this class, their difficulties, and whether they have been detected before
            object_boxes = true_class_boxes[true_class_images == this_image]  # (n_class_objects_in_img)
            object_difficulties = true_class_difficulties[true_class_images == this_image]  # (n_class_objects_in_img)
            # If no such object in this image, then the detection is a false positive
            if object_boxes.size(0) == 0:
                false_positives[d] = 1
                continue

            # Find maximum overlap of this detection with objects in this image of this class
            overlaps = find_jaccard_overlap(this_detection_box, object_boxes)  # (1, n_class_objects_in_img)
            max_overlap, ind = torch.max(overlaps.squeeze(0), dim=0)  # (), () - scalars

            # 'ind' is the index of the object in these image-level tensors 'object_boxes', 'object_difficulties'
            # In the original class-level tensors 'true_class_boxes', etc., 'ind' corresponds to object with index...
            original_ind = torch.LongTensor(range(true_class_boxes.size(0)))[true_class_images == this_image][ind]
            # We need 'original_ind' to update 'true_class_boxes_detected'

            # If the maximum overlap is greater than the threshold of 0.5, it's a match
            if max_overlap.item() > 0.5:
                # If the object it matched with is 'difficult', ignore it
                if object_difficulties[ind] == 0:
                    # If this object has already not been detected, it's a true positive
                    if true_class_boxes_detected[original_ind] == 0:
                        true_positives[d] = 1
                        true_class_boxes_detected[original_ind] = 1  # this object has now been detected/accounted for
                    # Otherwise, it's a false positive (since this object is already accounted for)
                    else:
                        false_positives[d] = 1
            # Otherwise, the detection occurs in a different location than the actual object, and is a false positive
            else:
                false_positives[d] = 1

        # Compute cumulative precision and recall at each detection in the order of decreasing scores
        cumul_true_positives = torch.cumsum(true_positives, dim=0)  # (n_class_detections)
        cumul_false_positives = torch.cumsum(false_positives, dim=0)  # (n_class_detections)
        cumul_precision = cumul_true_positives / (
                cumul_true_positives + cumul_false_positives + 1e-10)  # (n_class_detections)
        cumul_recall = cumul_true_positives / n_easy_class_objects  # (n_class_detections)

        # Find the mean of the maximum of the precisions corresponding to recalls above the threshold 't'
        recall_thresholds = torch.arange(start=0, end=1.1, step=.1).tolist()  # (11)
        precisions = torch.zeros((len(recall_thresholds)), dtype=torch.float).to(device)  # (11)
        for i, t in enumerate(recall_thresholds):
            recalls_above_t = cumul_recall >= t
            if recalls_above_t.any():
                precisions[i] = cumul_precision[recalls_above_t].max()
            else:
                precisions[i] = 0.
        average_precisions[c - 1] = precisions.mean()  # c is in [1, n_classes - 1]

    # Calculate Mean Average Precision (mAP)
    mean_average_precision = average_precisions.mean().item()

    # Keep class-wise average precisions in a dictionary
    average_precisions = {rev_label_map[c + 1]: v for c, v in enumerate(average_precisions.tolist())}

    return average_precisions, mean_average_precision

# %%
model = torchvision.models.detection.ssd300_vgg16(pretrained=True)
# load the model on to the computation device
model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=SSD300_VGG16_Weights.COCO_V1`. You can also use `weights=SSD300_VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/ssd300_vgg16_coco-b556d3b4.pth" to /root/.cache/torch/hub/checkpoints/ssd300_vgg16_coco-b556d3b4.pth
# 100%|██████████| 136M/136M [00:01<00:00, 101MB/s]
# SSD(
#   (backbone): SSDFeatureExtractorVGG(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU(inplace=True)
#       (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (6): ReLU(inplace=True)
#       (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (8): ReLU(inplace=True)
#       (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (13): ReLU(inplace=True)
#       (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (15): ReLU(inplace=True)
#       (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#       (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (18): ReLU(inplace=True)
#       (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (20): ReLU(inplace=True)
#       (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (22): ReLU(inplace=True)
#     )
#     (extra): ModuleList(
#       (0): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (6): ReLU(inplace=True)
#         (7): Sequential(
#           (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#           (1): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(6, 6), dilation=(6, 6))
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (4): ReLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (3): ReLU(inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (3): ReLU(inplace=True)
#       )
#       (3-4): 2 x Sequential(
#         (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#         (3): ReLU(inplace=True)
#       )
#     )
#   )
#   (anchor_generator): DefaultBoxGenerator(aspect_ratios=[[2], [2, 3], [2, 3], [2, 3], [2], [2]], clip=True, scales=[0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05], steps=[8, 16, 32, 64, 100, 300])
#   (head): SSDHead(
#     (classification_head): SSDClassificationHead(
#       (module_list): ModuleList(
#         (0): Conv2d(512, 364, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(1024, 546, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(512, 546, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 546, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4-5): 2 x Conv2d(256, 364, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (regression_head): SSDRegressionHead(
#       (module_list): ModuleList(
#         (0): Conv2d(512, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4-5): 2 x Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.48235, 0.45882, 0.40784], std=[0.00392156862745098, 0.00392156862745098, 0.00392156862745098])
#       Resize(min_size=(300,), max_size=300, mode='bilinear')
#   )
# )

# %%
class MultiBoxLoss(nn.Module):
    """
    The MultiBox loss, a loss function for object detection.
    This is a combination of:
    (1) a localization loss for the predicted locations of the boxes, and
    (2) a confidence loss for the predicted class scores.
    """

    def __init__(self, priors_cxcy, threshold=0.5, neg_pos_ratio=3, alpha=1.):
        super(MultiBoxLoss, self).__init__()
        self.priors_cxcy = priors_cxcy
        self.priors_xy = cxcy_to_xy(priors_cxcy)
        self.threshold = threshold
        self.neg_pos_ratio = neg_pos_ratio
        self.alpha = alpha

        self.smooth_l1 = nn.L1Loss()
        self.cross_entropy = nn.CrossEntropyLoss(reduce=False)
#         self.cross_entropy = nn.BCELoss()

    def forward(self, predicted_locs, predicted_scores, boxes, labels):
        """
        Forward propagation.
        :param predicted_locs: predicted locations/boxes w.r.t the 8732 prior boxes, a tensor of dimensions (N, 8732, 4)
        :param predicted_scores: class scores for each of the encoded locations/boxes, a tensor of dimensions (N, 8732, n_classes)
        :param boxes: true  object bounding boxes in boundary coordinates, a list of N tensors
        :param labels: true object labels, a list of N tensors
        :return: multibox loss, a scalar
        """
        batch_size = predicted_locs.size(0)
        n_priors = self.priors_cxcy.size(0)
        n_classes = predicted_scores.size(2)

        assert n_priors == predicted_locs.size(1) == predicted_scores.size(1)

        true_locs = torch.zeros((batch_size, n_priors, 4), dtype=torch.float).cuda()  # (N, 8732, 4)
        true_classes = torch.zeros((batch_size, n_priors), dtype=torch.long).cuda()  # (N, 8732)

        # For each image
        for i in range(batch_size):
            n_objects = boxes[i].size(0)

            overlap = find_jaccard_overlap(boxes[i],
                                           self.priors_xy)  # (n_objects, 8732)

            # For each prior, find the object that has the maximum overlap
            overlap_for_each_prior, object_for_each_prior = overlap.max(dim=0)  # (8732)

            # First, find the prior that has the maximum overlap for each object.
            _, prior_for_each_object = overlap.max(dim=1)  # (N_o)

            # Then, assign each object to the corresponding maximum-overlap-prior. (This fixes 1.)
            object_for_each_prior[prior_for_each_object] = torch.LongTensor(range(n_objects)).cuda()

            # To ensure these priors qualify, artificially give them an overlap of greater than 0.5. (This fixes 2.)
            overlap_for_each_prior[prior_for_each_object] = 1.

            # Labels for each prior
            label_for_each_prior = labels[i][object_for_each_prior]  # (8732)
            # Set priors whose overlaps with objects are less than the threshold to be background (no object)
            label_for_each_prior[overlap_for_each_prior < self.threshold] = 0  # (8732)

            # Store
            true_classes[i] = label_for_each_prior

            # Encode center-size object coordinates into the form we regressed predicted boxes to
            true_locs[i] = cxcy_to_gcxgcy(xy_to_cxcy(boxes[i][object_for_each_prior]), self.priors_cxcy)  # (8732, 4)

        # Identify priors that are positive (object/non-background)
        positive_priors = true_classes != 0  # (N, 8732)

        # LOCALIZATION LOSS

        loc_loss = self.smooth_l1(predicted_locs[positive_priors], true_locs[positive_priors])  # (), scalar

        n_positives = positive_priors.sum(dim=1)  # (N)
        n_hard_negatives = self.neg_pos_ratio * n_positives  # (N)

        # CONFIDENCE LOSS

        conf_loss_all = self.cross_entropy(predicted_scores.view(-1, n_classes), true_classes.view(-1))  # (N * 8732)
        conf_loss_all = conf_loss_all.view(batch_size, n_priors)  # (N, 8732)

        conf_loss_pos = conf_loss_all[positive_priors]  # (sum(n_positives))

        conf_loss_neg = conf_loss_all.clone()  # (N, 8732)
        conf_loss_neg[positive_priors] = 0.  # (N, 8732), positive priors are ignored (never in top n_hard_negatives)
        conf_loss_neg, _ = conf_loss_neg.sort(dim=1, descending=True)  # (N, 8732), sorted by decreasing hardness
        hardness_ranks = torch.LongTensor(range(n_priors)).unsqueeze(0).expand_as(conf_loss_neg).cuda()  # (N, 8732)
        hard_negatives = hardness_ranks < n_hard_negatives.unsqueeze(1)  # (N, 8732)
        conf_loss_hard_neg = conf_loss_neg[hard_negatives]  # (sum(n_hard_negatives))

        conf_loss = (conf_loss_hard_neg.sum() + conf_loss_pos.sum()) / n_positives.sum().float()  # (), scalar

        # TOTAL LOSS

        return conf_loss + self.alpha * loc_loss

# %%
EPOCH = 5
LR = 0.0001
BS = 8
momentum = 0.9  # momentum
weight_decay = 5e-4  # weight decay
print_feq = 100

# %%
# model = SSD(n_classes=2).cuda()
# criterion = MultiBoxLoss(priors_cxcy=model.priors_cxcy).cuda()
optimizer = torch.optim.SGD(model.parameters(), lr=LR, momentum=momentum, weight_decay=weight_decay)

# %%
train_ds = DogDataSet(all_img_name[:int(len(all_img_name)*0.8)], transform=tsfm)
train_dl = DataLoader(train_ds, batch_size=BS, shuffle=True,collate_fn=utils.collate_fn)

valid_ds = DogDataSet(all_img_name[int(len(all_img_name)*0.8):int(len(all_img_name)*0.9)], transform=tsfm)
valid_dl = DataLoader(valid_ds, batch_size=BS, shuffle=True,collate_fn=utils.collate_fn)
grad_clip = True

# %%
from tqdm import tqdm
import time

for epoch in range(1, EPOCH+1):
    model.train()
    train_loss = []
    start_time = time.time()
    train_loss = []
    model.train()
    print(f'Epoch :{epoch}')
    for (images, targets) in train_dl:
        images = [image.to(device) for image in images]
        
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        train_loss.append(losses.item()) 
        # Gradient clipping
        if grad_clip: 
            nn.utils.clip_grad_value_(model.parameters(), grad_clip)   
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
    print('epoch:', epoch, '/', EPOCH,
            '\ttrain loss:', '{:.4f}'.format(np.mean(train_loss)))
# Out:
# Epoch :1
# epoch: 1 / 5 	train loss: 2.7927
# Epoch :2
# epoch: 2 / 5 	train loss: 1.7169
# Epoch :3
# epoch: 3 / 5 	train loss: 1.6682
# Epoch :4
# epoch: 4 / 5 	train loss: 1.6329
# Epoch :5
# epoch: 5 / 5 	train loss: 1.6038

# %%
model.eval();
del train_ds, train_dl, valid_ds, valid_dl

# %%
from random import randint

def test(n=5):
    d = []
    model.eval()
    for i in range(5):
        origin_img = Image.open('../content/Images/' + all_img_name[-1*randint(1,100)]).convert('RGB')
        img = tsfm(origin_img)

        img = img.cuda()
        output = model(img.unsqueeze(0))
        det_boxes, det_labels, det_scores = output[0]['boxes'],output[0]['labels'],output[0]['scores']
        det_boxes = det_boxes[0].to('cpu')
        
        origin_dims = torch.FloatTensor([origin_img.width, origin_img.height, origin_img.width, origin_img.height]).unsqueeze(0)
        det_boxes = det_boxes * origin_dims

        annotated_image = origin_img
        draw = ImageDraw.Draw(annotated_image)

        box_location = det_boxes[0].tolist()
        draw.rectangle(xy=box_location, outline='red')
        draw.rectangle(xy=list(map(lambda x:x+1, box_location)), outline='red')
        d.append(annotated_image)
    return d

# %%
for i in test():
    plt.figure(figsize=(5, 5))
    plt.imshow(i)

# %%
from engine import evaluate

model.eval()
evaluate(model, valid_dl, device=device)
# Out:
# creating index...
# index created!
# Test:  [  0/258]  eta: 0:01:31  model_time: 0.3010 (0.3010)  evaluator_time: 0.0055 (0.0055)  time: 0.3528  data: 0.0436  max mem: 1329
# Test:  [100/258]  eta: 0:00:42  model_time: 0.2129 (0.2157)  evaluator_time: 0.0030 (0.0031)  time: 0.2666  data: 0.0455  max mem: 1329
# Test:  [200/258]  eta: 0:00:15  model_time: 0.2159 (0.2161)  evaluator_time: 0.0030 (0.0031)  time: 0.2693  data: 0.0457  max mem: 1329
# Test:  [257/258]  eta: 0:00:00  model_time: 0.2162 (0.2155)  evaluator_time: 0.0031 (0.0031)  time: 0.2602  data: 0.0449  max mem: 1329
# Test: Total time: 0:01:09 (0.2680 s / it)
# Averaged stats: model_time: 0.2162 (0.2155)  evaluator_time: 0.0031 (0.0031)
# Accumulating evaluation results...
# DONE (t=0.13s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.194
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.190

# %%
# class VGGBase(nn.Module):
#     """
#     VGG base convolutions to produce lower-level feature maps.
#     """

#     def __init__(self):
#         super(VGGBase, self).__init__()

#         # Standard convolutional layers in VGG16
#         self.conv1_1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)  # stride = 1, by default
#         self.conv1_2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
#         self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

#         self.conv2_1 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
#         self.conv2_2 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
#         self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

#         self.conv3_1 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
#         self.conv3_2 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
#         self.conv3_3 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
#         self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2, ceil_mode=True)  # ceiling (not floor) here for even dims

#         self.conv4_1 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
#         self.conv4_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
#         self.conv4_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
#         self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

#         self.conv5_1 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
#         self.conv5_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
#         self.conv5_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
#         self.pool5 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)  # retains size because stride is 1 (and padding)

#         # Replacements for FC6 and FC7 in VGG16
#         self.conv6 = nn.Conv2d(512, 1024, kernel_size=3, padding=6, dilation=6)  # atrous convolution

#         self.conv7 = nn.Conv2d(1024, 1024, kernel_size=1)

#         # Load pretrained layers
#         self.load_pretrained_layers()

#     def forward(self, image):
#         """
#         Forward propagation.
#         :param image: images, a tensor of dimensions (N, 3, 300, 300)
#         :return: lower-level feature maps conv4_3 and conv7
#         """
#         out = F.relu(self.conv1_1(image))  # (N, 64, 300, 300)
#         out = F.relu(self.conv1_2(out))  # (N, 64, 300, 300)
#         out = self.pool1(out)  # (N, 64, 150, 150)

#         out = F.relu(self.conv2_1(out))  # (N, 128, 150, 150)
#         out = F.relu(self.conv2_2(out))  # (N, 128, 150, 150)
#         out = self.pool2(out)  # (N, 128, 75, 75)

#         out = F.relu(self.conv3_1(out))  # (N, 256, 75, 75)
#         out = F.relu(self.conv3_2(out))  # (N, 256, 75, 75)
#         out = F.relu(self.conv3_3(out))  # (N, 256, 75, 75)
#         out = self.pool3(out)  # (N, 256, 38, 38), it would have been 37 if not for ceil_mode = True

#         out = F.relu(self.conv4_1(out))  # (N, 512, 38, 38)
#         out = F.relu(self.conv4_2(out))  # (N, 512, 38, 38)
#         out = F.relu(self.conv4_3(out))  # (N, 512, 38, 38)
#         conv4_3_feats = out  # (N, 512, 38, 38)
#         out = self.pool4(out)  # (N, 512, 19, 19)

#         out = F.relu(self.conv5_1(out))  # (N, 512, 19, 19)
#         out = F.relu(self.conv5_2(out))  # (N, 512, 19, 19)
#         out = F.relu(self.conv5_3(out))  # (N, 512, 19, 19)
#         out = self.pool5(out)  # (N, 512, 19, 19), pool5 does not reduce dimensions

#         out = F.relu(self.conv6(out))  # (N, 1024, 19, 19)

#         conv7_feats = F.relu(self.conv7(out))  # (N, 1024, 19, 19)

#         # Lower-level feature maps
#         return conv4_3_feats, conv7_feats

#     def load_pretrained_layers(self):
#         """
#         As in the paper, we use a VGG-16 pretrained on the ImageNet task as the base network.
#         There's one available in PyTorch, see https://pytorch.org/docs/stable/torchvision/models.html#torchvision.models.vgg16
#         We copy these parameters into our network. It's straightforward for conv1 to conv5.
#         However, the original VGG-16 does not contain the conv6 and con7 layers.
#         Therefore, we convert fc6 and fc7 into convolutional layers, and subsample by decimation. See 'decimate' in utils.py.
#         """
#         # Current state of base
#         state_dict = self.state_dict()
#         param_names = list(state_dict.keys())

#         # Pretrained VGG base
#         pretrained_state_dict = torchvision.models.vgg16(weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1).state_dict()
#         pretrained_param_names = list(pretrained_state_dict.keys())

#         # Transfer conv. parameters from pretrained model to current model
#         for i, param in enumerate(param_names[:-4]):  # excluding conv6 and conv7 parameters
#             state_dict[param] = pretrained_state_dict[pretrained_param_names[i]]

#         # Convert fc6, fc7 to convolutional layers, and subsample (by decimation) to sizes of conv6 and conv7
#         # fc6
#         conv_fc6_weight = pretrained_state_dict['classifier.0.weight'].view(4096, 512, 7, 7)  # (4096, 512, 7, 7)
#         conv_fc6_bias = pretrained_state_dict['classifier.0.bias']  # (4096)
#         state_dict['conv6.weight'] = decimate(conv_fc6_weight, m=[4, None, 3, 3])  # (1024, 512, 3, 3)
#         state_dict['conv6.bias'] = decimate(conv_fc6_bias, m=[4])  # (1024)
#         # fc7
#         conv_fc7_weight = pretrained_state_dict['classifier.3.weight'].view(4096, 4096, 1, 1)  # (4096, 4096, 1, 1)
#         conv_fc7_bias = pretrained_state_dict['classifier.3.bias']  # (4096)
#         state_dict['conv7.weight'] = decimate(conv_fc7_weight, m=[4, 4, None, None])  # (1024, 1024, 1, 1)
#         state_dict['conv7.bias'] = decimate(conv_fc7_bias, m=[4])  # (1024)

#         # Note: an FC layer of size (K) operating on a flattened version (C*H*W) of a 2D image of size (C, H, W)...
#         # ...is equivalent to a convolutional layer with kernel size (H, W), input channels C, output channels K...
#         # ...operating on the 2D image of size (C, H, W) without padding

#         self.load_state_dict(state_dict)

#         print("\nLoaded base model.\n")
        

# class AuxiliaryConvolutions(nn.Module):
#     def __init__(self):
#         super(AuxiliaryConvolutions, self).__init__()
#         self.conv8_1 = nn.Conv2d(1024, 256, kernel_size=1, padding=0)  # stride = 1, by default
#         self.conv8_2 = nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1)  # dim. reduction because stride > 1

#         self.conv9_1 = nn.Conv2d(512, 128, kernel_size=1, padding=0)
#         self.conv9_2 = nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1)  # dim. reduction because stride > 1

#         self.conv10_1 = nn.Conv2d(256, 128, kernel_size=1, padding=0)
#         self.conv10_2 = nn.Conv2d(128, 256, kernel_size=3, padding=0)  # dim. reduction because padding = 0

#         self.conv11_1 = nn.Conv2d(256, 128, kernel_size=1, padding=0)
#         self.conv11_2 = nn.Conv2d(128, 256, kernel_size=3, padding=0)  # dim. reduction because padding = 0
        
#         self.init_conv2d()
        
#     def init_conv2d(self):
#         """
#         Initialize convolution parameters.
#         """
#         for c in self.children():
#             if isinstance(c, nn.Conv2d):
#                 nn.init.xavier_uniform_(c.weight)
#                 nn.init.constant_(c.bias, 0.)
        
#     def forward(self, conv7_feats):
#         out = F.relu(self.conv8_1(conv7_feats))  # (N, 256, 19, 19)
#         out = F.relu(self.conv8_2(out))  # (N, 512, 10, 10)
#         conv8_2_feats = out  # (N, 512, 10, 10)

#         out = F.relu(self.conv9_1(out))  # (N, 128, 10, 10)
#         out = F.relu(self.conv9_2(out))  # (N, 256, 5, 5)
#         conv9_2_feats = out  # (N, 256, 5, 5)

#         out = F.relu(self.conv10_1(out))  # (N, 128, 5, 5)
#         out = F.relu(self.conv10_2(out))  # (N, 256, 3, 3)
#         conv10_2_feats = out  # (N, 256, 3, 3)

#         out = F.relu(self.conv11_1(out))  # (N, 128, 3, 3)
#         conv11_2_feats = F.relu(self.conv11_2(out))  # (N, 256, 1, 1)

#         # Higher-level feature maps
#         return conv8_2_feats, conv9_2_feats, conv10_2_feats, conv11_2_feats
    
# class PredictionConvolutions(nn.Module):
#     def __init__(self, n_classes):
#         super(PredictionConvolutions, self).__init__()
#         self.n_classes = n_classes
        
#         n_boxes = {'conv4_3': 4,
#                    'conv7': 6,
#                    'conv8_2': 6,
#                    'conv9_2': 6,
#                    'conv10_2': 4,
#                    'conv11_2': 4}
        
#         # Localization prediction convolutions (predict offsets w.r.t prior-boxes)
#         self.loc_conv4_3 = nn.Conv2d(512, n_boxes['conv4_3'] * 4, kernel_size=3, padding=1)
#         self.loc_conv7 = nn.Conv2d(1024, n_boxes['conv7'] * 4, kernel_size=3, padding=1)
#         self.loc_conv8_2 = nn.Conv2d(512, n_boxes['conv8_2'] * 4, kernel_size=3, padding=1)
#         self.loc_conv9_2 = nn.Conv2d(256, n_boxes['conv9_2'] * 4, kernel_size=3, padding=1)
#         self.loc_conv10_2 = nn.Conv2d(256, n_boxes['conv10_2'] * 4, kernel_size=3, padding=1)
#         self.loc_conv11_2 = nn.Conv2d(256, n_boxes['conv11_2'] * 4, kernel_size=3, padding=1)

#         # Class prediction convolutions (predict classes in localization boxes)
#         self.cl_conv4_3 = nn.Conv2d(512, n_boxes['conv4_3'] * n_classes, kernel_size=3, padding=1)
#         self.cl_conv7 = nn.Conv2d(1024, n_boxes['conv7'] * n_classes, kernel_size=3, padding=1)
#         self.cl_conv8_2 = nn.Conv2d(512, n_boxes['conv8_2'] * n_classes, kernel_size=3, padding=1)
#         self.cl_conv9_2 = nn.Conv2d(256, n_boxes['conv9_2'] * n_classes, kernel_size=3, padding=1)
#         self.cl_conv10_2 = nn.Conv2d(256, n_boxes['conv10_2'] * n_classes, kernel_size=3, padding=1)
#         self.cl_conv11_2 = nn.Conv2d(256, n_boxes['conv11_2'] * n_classes, kernel_size=3, padding=1)
        
#         self.init_conv2d()
        
#     def init_conv2d(self):
#         for c in self.children():
#             if isinstance(c, nn.Conv2d):
#                 nn.init.xavier_uniform_(c.weight)
#                 nn.init.constant_(c.bias, 0.)

#     def forward(self, conv4_3_feats, conv7_feats, conv8_2_feats, conv9_2_feats, conv10_2_feats, conv11_2_feats):
#         batch_size = conv4_3_feats.size(0)

#         # Predict localization boxes' bounds (as offsets w.r.t prior-boxes)
#         l_conv4_3 = self.loc_conv4_3(conv4_3_feats)  # (N, 16, 38, 38)
#         l_conv4_3 = l_conv4_3.permute(0, 2, 3, 1).contiguous()  # (N, 38, 38, 16), to match prior-box order (after .view())
#         # (.contiguous() ensures it is stored in a contiguous chunk of memory, needed for .view() below)
#         l_conv4_3 = l_conv4_3.view(batch_size, -1, 4)  # (N, 5776, 4), there are a total 5776 boxes on this feature map

#         l_conv7 = self.loc_conv7(conv7_feats)  # (N, 24, 19, 19)
#         l_conv7 = l_conv7.permute(0, 2, 3, 1).contiguous()  # (N, 19, 19, 24)
#         l_conv7 = l_conv7.view(batch_size, -1, 4)  # (N, 2166, 4), there are a total 2116 boxes on this feature map

#         l_conv8_2 = self.loc_conv8_2(conv8_2_feats)  # (N, 24, 10, 10)
#         l_conv8_2 = l_conv8_2.permute(0, 2, 3, 1).contiguous()  # (N, 10, 10, 24)
#         l_conv8_2 = l_conv8_2.view(batch_size, -1, 4)  # (N, 600, 4)

#         l_conv9_2 = self.loc_conv9_2(conv9_2_feats)  # (N, 24, 5, 5)
#         l_conv9_2 = l_conv9_2.permute(0, 2, 3, 1).contiguous()  # (N, 5, 5, 24)
#         l_conv9_2 = l_conv9_2.view(batch_size, -1, 4)  # (N, 150, 4)

#         l_conv10_2 = self.loc_conv10_2(conv10_2_feats)  # (N, 16, 3, 3)
#         l_conv10_2 = l_conv10_2.permute(0, 2, 3, 1).contiguous()  # (N, 3, 3, 16)
#         l_conv10_2 = l_conv10_2.view(batch_size, -1, 4)  # (N, 36, 4)

#         l_conv11_2 = self.loc_conv11_2(conv11_2_feats)  # (N, 16, 1, 1)
#         l_conv11_2 = l_conv11_2.permute(0, 2, 3, 1).contiguous()  # (N, 1, 1, 16)
#         l_conv11_2 = l_conv11_2.view(batch_size, -1, 4)  # (N, 4, 4)

#         # Predict classes in localization boxes
#         c_conv4_3 = self.cl_conv4_3(conv4_3_feats)  # (N, 4 * n_classes, 38, 38)
#         c_conv4_3 = c_conv4_3.permute(0, 2, 3, 1).contiguous()  # (N, 38, 38, 4 * n_classes), to match prior-box order (after .view())
#         c_conv4_3 = c_conv4_3.view(batch_size, -1, self.n_classes)  # (N, 5776, n_classes), there are a total 5776 boxes on this feature map

#         c_conv7 = self.cl_conv7(conv7_feats)  # (N, 6 * n_classes, 19, 19)
#         c_conv7 = c_conv7.permute(0, 2, 3, 1).contiguous()  # (N, 19, 19, 6 * n_classes)
#         c_conv7 = c_conv7.view(batch_size, -1, self.n_classes)  # (N, 2166, n_classes), there are a total 2116 boxes on this feature map

#         c_conv8_2 = self.cl_conv8_2(conv8_2_feats)  # (N, 6 * n_classes, 10, 10)
#         c_conv8_2 = c_conv8_2.permute(0, 2, 3, 1).contiguous()  # (N, 10, 10, 6 * n_classes)
#         c_conv8_2 = c_conv8_2.view(batch_size, -1, self.n_classes)  # (N, 600, n_classes)

#         c_conv9_2 = self.cl_conv9_2(conv9_2_feats)  # (N, 6 * n_classes, 5, 5)
#         c_conv9_2 = c_conv9_2.permute(0, 2, 3, 1).contiguous()  # (N, 5, 5, 6 * n_classes)
#         c_conv9_2 = c_conv9_2.view(batch_size, -1, self.n_classes)  # (N, 150, n_classes)

#         c_conv10_2 = self.cl_conv10_2(conv10_2_feats)  # (N, 4 * n_classes, 3, 3)
#         c_conv10_2 = c_conv10_2.permute(0, 2, 3, 1).contiguous()  # (N, 3, 3, 4 * n_classes)
#         c_conv10_2 = c_conv10_2.view(batch_size, -1, self.n_classes)  # (N, 36, n_classes)

#         c_conv11_2 = self.cl_conv11_2(conv11_2_feats)  # (N, 4 * n_classes, 1, 1)
#         c_conv11_2 = c_conv11_2.permute(0, 2, 3, 1).contiguous()  # (N, 1, 1, 4 * n_classes)
#         c_conv11_2 = c_conv11_2.view(batch_size, -1, self.n_classes)  # (N, 4, n_classes)

#         # A total of 8732 boxes
#         # Concatenate in this specific order (i.e. must match the order of the prior-boxes)
#         locs = torch.cat([l_conv4_3, l_conv7, l_conv8_2, l_conv9_2, l_conv10_2, l_conv11_2], dim=1)  # (N, 8732, 4)
#         classes_scores = torch.cat([c_conv4_3, c_conv7, c_conv8_2, c_conv9_2, c_conv10_2, c_conv11_2], dim=1)  # (N, 8732, n_classes)

#         return locs, classes_scores
    
# class SSD(nn.Module):
#     def __init__(self, n_classes=2):
#         super(SSD, self).__init__()
#         self.n_classes = n_classes
        
#         self.base = VGGBase().cuda()
#         self.aux_convs = AuxiliaryConvolutions().cuda()
#         self.pred_convs = PredictionConvolutions(n_classes).cuda()
        
#         self.rescale_factors = nn.Parameter(torch.FloatTensor(1, 512, 1, 1))  # there are 512 channels in conv4_3_feats
#         nn.init.constant_(self.rescale_factors, 20)

#         # Prior boxes
#         self.priors_cxcy = self.create_prior_boxes()
        
#     def forward(self, image):
#         """
#         Forward propagation.
#         :param image: images, a tensor of dimensions (N, 3, 300, 300)
#         :return: 8732 locations and class scores (i.e. w.r.t each prior box) for each image
#         """
#         # Run VGG base network convolutions (lower level feature map generators)
#         conv4_3_feats, conv7_feats = self.base(image)  # (N, 512, 38, 38), (N, 1024, 19, 19)

#         # Rescale conv4_3 after L2 norm
#         norm = conv4_3_feats.pow(2).sum(dim=1, keepdim=True).sqrt()  # (N, 1, 38, 38)
#         conv4_3_feats = conv4_3_feats / norm  # (N, 512, 38, 38)
#         conv4_3_feats = conv4_3_feats * self.rescale_factors  # (N, 512, 38, 38)
#         # (PyTorch autobroadcasts singleton dimensions during arithmetic)

#         # Run auxiliary convolutions (higher level feature map generators)
#         conv8_2_feats, conv9_2_feats, conv10_2_feats, conv11_2_feats = self.aux_convs(conv7_feats)  # (N, 512, 10, 10),  (N, 256, 5, 5), (N, 256, 3, 3), (N, 256, 1, 1)

#         # Run prediction convolutions (predict offsets w.r.t prior-boxes and classes in each resulting localization box)
#         locs, classes_scores = self.pred_convs(conv4_3_feats, conv7_feats, conv8_2_feats, conv9_2_feats, conv10_2_feats,
#                                                conv11_2_feats)  # (N, 8732, 4), (N, 8732, n_classes)

#         return locs, classes_scores

    
#     def create_prior_boxes(self):
#         """
#         Create the 8732 prior (default) boxes for the SSD300, as defined in the paper.
#         :return: prior boxes in center-size coordinates, a tensor of dimensions (8732, 4)
#         """
#         fmap_dims = {'conv4_3': 38,
#                      'conv7': 19,
#                      'conv8_2': 10,
#                      'conv9_2': 5,
#                      'conv10_2': 3,
#                      'conv11_2': 1}

#         obj_scales = {'conv4_3': 0.1,
#                       'conv7': 0.2,
#                       'conv8_2': 0.375,
#                       'conv9_2': 0.55,
#                       'conv10_2': 0.725,
#                       'conv11_2': 0.9}

#         aspect_ratios = {'conv4_3': [1., 2., 0.5],
#                          'conv7': [1., 2., 3., 0.5, .333],
#                          'conv8_2': [1., 2., 3., 0.5, .333],
#                          'conv9_2': [1., 2., 3., 0.5, .333],
#                          'conv10_2': [1., 2., 0.5],
#                          'conv11_2': [1., 2., 0.5]}

#         fmaps = list(fmap_dims.keys())

#         prior_boxes = []

#         for k, fmap in enumerate(fmaps):
#             for i in range(fmap_dims[fmap]):
#                 for j in range(fmap_dims[fmap]):
#                     cx = (j + 0.5) / fmap_dims[fmap]
#                     cy = (i + 0.5) / fmap_dims[fmap]

#                     for ratio in aspect_ratios[fmap]:
#                         prior_boxes.append([cx, cy, obj_scales[fmap] * sqrt(ratio), obj_scales[fmap] / sqrt(ratio)])

#                         # For an aspect ratio of 1, use an additional prior whose scale is the geometric mean of the
#                         # scale of the current feature map and the scale of the next feature map
#                         if ratio == 1.:
#                             try:
#                                 additional_scale = sqrt(obj_scales[fmap] * obj_scales[fmaps[k + 1]])
#                             # For the last feature map, there is no "next" feature map
#                             except IndexError:
#                                 additional_scale = 1.
#                             prior_boxes.append([cx, cy, additional_scale, additional_scale])

#         prior_boxes = torch.FloatTensor(prior_boxes).cuda()  # (8732, 4)
#         prior_boxes.clamp_(0, 1)  # (8732, 4)

#         return prior_boxes
    
#     def detect_objects(self, predicted_locs, predicted_scores, min_score, max_overlap, top_k):
#         """
#         Decipher the 8732 locations and class scores (output of ths SSD300) to detect objects.
#         For each class, perform Non-Maximum Suppression (NMS) on boxes that are above a minimum threshold.
#         :param predicted_locs: predicted locations/boxes w.r.t the 8732 prior boxes, a tensor of dimensions (N, 8732, 4)
#         :param predicted_scores: class scores for each of the encoded locations/boxes, a tensor of dimensions (N, 8732, n_classes)
#         :param min_score: minimum threshold for a box to be considered a match for a certain class
#         :param max_overlap: maximum overlap two boxes can have so that the one with the lower score is not suppressed via NMS
#         :param top_k: if there are a lot of resulting detection across all classes, keep only the top 'k'
#         :return: detections (boxes, labels, and scores), lists of length batch_size
#         """
#         batch_size = predicted_locs.size(0)
#         n_priors = self.priors_cxcy.size(0)
# #         print(n_priors)
#         predicted_scores = F.softmax(predicted_scores, dim=2)  # (N, 8732, n_classes)

#         # Lists to store final predicted boxes, labels, and scores for all images
#         all_images_boxes = list()
#         all_images_labels = list()
#         all_images_scores = list()

#         assert n_priors == predicted_locs.size(1) == predicted_scores.size(1)

#         for i in range(batch_size):
#             # Decode object coordinates from the form we regressed predicted boxes to
#             decoded_locs = cxcy_to_xy(
#                 gcxgcy_to_cxcy(predicted_locs[i], self.priors_cxcy))  # (8732, 4), these are fractional pt. coordinates

#             # Lists to store boxes and scores for this image
#             image_boxes = list()
#             image_labels = list()
#             image_scores = list()

#             max_scores, best_label = predicted_scores[i].max(dim=1)  # (8732)

#             # Check for each class
#             for c in range(1, self.n_classes):
#                 # Keep only predicted boxes and scores where scores for this class are above the minimum score
#                 class_scores = predicted_scores[i][:, c]  # (8732)
#                 score_above_min_score = class_scores > min_score  # torch.uint8 (byte) tensor, for indexing
#                 n_above_min_score = score_above_min_score.sum().item()
#                 if n_above_min_score == 0:
#                     continue
#                 class_scores = class_scores[score_above_min_score]  # (n_qualified), n_min_score <= 8732
#                 class_decoded_locs = decoded_locs[score_above_min_score]  # (n_qualified, 4)

#                 # Sort predicted boxes and scores by scores
#                 class_scores, sort_ind = class_scores.sort(dim=0, descending=True)  # (n_qualified), (n_min_score)
#                 class_decoded_locs = class_decoded_locs[sort_ind]  # (n_min_score, 4)

#                 # Find the overlap between predicted boxes
#                 overlap = find_jaccard_overlap(class_decoded_locs, class_decoded_locs)  # (n_qualified, n_min_score)

#                 # Non-Maximum Suppression (NMS)

#                 # A torch.uint8 (byte) tensor to keep track of which predicted boxes to suppress
#                 # 1 implies suppress, 0 implies don't suppress
#                 suppress = torch.zeros((n_above_min_score), dtype=torch.uint8).cuda()  # (n_qualified)

#                 # Consider each box in order of decreasing scores
#                 for box in range(class_decoded_locs.size(0)):
#                     # If this box is already marked for suppression
#                     if suppress[box] == 1:
#                         continue

#                     # Suppress boxes whose overlaps (with this box) are greater than maximum overlap
#                     # Find such boxes and update suppress indices
#                     suppress = torch.max(suppress, overlap[box] > max_overlap)
#                     # The max operation retains previously suppressed boxes, like an 'OR' operation

#                     # Don't suppress this box, even though it has an overlap of 1 with itself
#                     suppress[box] = 0

#                 # Store only unsuppressed boxes for this class
#                 image_boxes.append(class_decoded_locs[1 - suppress])
#                 image_labels.append(torch.LongTensor((1 - suppress).sum().item() * [c]).cuda())
#                 image_scores.append(class_scores[1 - suppress])

#             # If no object in any class is found, store a placeholder for 'background'
#             if len(image_boxes) == 0:
#                 image_boxes.append(torch.FloatTensor([[0., 0., 1., 1.]]).cuda())
#                 image_labels.append(torch.LongTensor([0]).cuda())
#                 image_scores.append(torch.FloatTensor([0.]).cuda())

#             # Concatenate into single tensors
#             image_boxes = torch.cat(image_boxes, dim=0)  # (n_objects, 4)
#             image_labels = torch.cat(image_labels, dim=0)  # (n_objects)
#             image_scores = torch.cat(image_scores, dim=0)  # (n_objects)
#             n_objects = image_scores.size(0)

#             # Keep only the top k objects
#             if n_objects > top_k:
#                 image_scores, sort_ind = image_scores.sort(dim=0, descending=True)
#                 image_scores = image_scores[:top_k]  # (top_k)
#                 image_boxes = image_boxes[sort_ind][:top_k]  # (top_k, 4)
#                 image_labels = image_labels[sort_ind][:top_k]  # (top_k)

#             # Append to lists that store predicted boxes and scores for all images
#             all_images_boxes.append(image_boxes)
#             all_images_labels.append(image_labels)
#             all_images_scores.append(image_scores)

#         return all_images_boxes, all_images_labels, all_images_scores  # lists of length batch_size
